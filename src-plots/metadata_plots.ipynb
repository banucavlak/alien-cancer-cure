# %%
import IPython

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### **1 Reading Metadata File**

# %%
df_meta = pd.read_csv('../data/metadata/str_metadata.tsv', sep='\t')

# %%
df_meta.head()
# Out:
#   sampleid stool_consistency hct_source                    disease  \
# 0   N4VICF            formed       cord  Myelodysplastic Syndromes
# 1   8A0F9A            formed       cord                   Leukemia
# 2   5Y49IM       semi-formed       cord                   Leukemia
# 3   ZKJI45       semi-formed       cord                   Leukemia
# 4   2I7SIQ            liquid       cord                   Leukemia
#
#   categorical_time_relative_to_engraftment  week_relative_to_hct  \
# 0                                      pre   one week before HCT
# 1                                      pre  two weeks before HCT
# 2                                     peri   one week before HCT
# 3                                     post    one week after HCT
# 4                                     peri   one week before HCT
#
#    timepoint_of_transplant  day_relative_to_nearest_hct alleged_abduction
# 0                      6.0                         -6.0      non_abducted
# ...

# %%
import seaborn as sns

fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="disease", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)
#plt.legend(fontsize='large')


#xtick_labels = ['non abducted', 'abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Diseases across Alien Abduction', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.setp(ax.get_legend().get_texts(), fontsize='8') # for legend text


plt.savefig("../plots/metadata/metadata_disease" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="hct_source", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Hct Source across Alien Abduction', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.setp(ax.get_legend().get_texts(), fontsize='8') # for legend text


plt.savefig("../plots/metadata/metadata_hct_source" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="categorical_time_relative_to_engraftment", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Time across Alien Abduction', fontsize=16);
plt.setp(ax.get_legend().get_texts(), fontsize='10') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='10') # for legend title


plt.savefig("../plots/metadata/metadata_categorical_time" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="stool_consistency", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Stool Consistency across Alien Abduction', fontsize=16);
plt.setp(ax.get_legend().get_texts(), fontsize='10') # for legend text

plt.savefig("../plots/metadata/metadata_stool_consistency" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="week_relative_to_hct", hue="disease", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)

#ax.set_xticklabels(xtick_labels, fontsize=10);
#ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
ax.set_xlabel('HCT Time', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of disease across HCT Time', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.setp(ax.get_legend().get_texts(), fontsize='10') # for legend text

#plt.savefig("../plots/metadata/metadata_hct_disease" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')
# Out:
# [None, None, None, None, None, None, None, None]

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="week_relative_to_hct", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Time across Alien Abduction', fontsize=16);
plt.setp(ax.get_legend().get_texts(), fontsize='10') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='10') # for legend title
#ax.add_legend(label_order = ['two week before HCT','one week before HCT','HCT week','one week after HCT','two weeks after HCT'])

#plt.savefig("../plots/metadata/metadata_hct_abduction" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')
# Out:
# [None, None]

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="stool_consistency", hue="categorical_time_relative_to_engraftment", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Stool consistency', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Time across Alien Abduction', fontsize=16);
plt.setp(ax.get_legend().get_texts(), fontsize='10') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='10') # for legend title

#plt.savefig("../plots/metadata/metadata_stool_engraftment" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="stool_consistency", hue="week_relative_to_hct", multiple='dodge', discrete=True, ax=ax, shrink=0.8
)

xtick_labels = ['Two Weeks Before HCT','One Week Before HCT','HCT Week','One Week After HCT', 'Two Weeks After HCT']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Stool consistency', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Time across Alien Abduction', fontsize=16);
plt.setp(ax.get_legend().get_texts(), fontsize='10') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='10') # for legend title

plt.savefig("../plots/metadata/metadata_stool_HCT_week" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')
