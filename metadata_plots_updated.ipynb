# %%
import IPython

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_dir = 'Alien_data'

# %% [markdown]
# ### **1 Reading Metadata File**

# %%
df_meta = pd.read_csv('Alien_data/str_metadata.tsv', sep='\t')

# %%
df_meta.head()
# Out:
#   sampleid stool_consistency hct_source                    disease  \
# 0   N4VICF            formed       cord  Myelodysplastic Syndromes
# 1   8A0F9A            formed       cord                   Leukemia
# 2   5Y49IM       semi-formed       cord                   Leukemia
# 3   ZKJI45       semi-formed       cord                   Leukemia
# 4   2I7SIQ            liquid       cord                   Leukemia
#
#   categorical_time_relative_to_engraftment  week_relative_to_hct  \
# 0                                      pre   one week before HCT
# 1                                      pre  two weeks before HCT
# 2                                     peri   one week before HCT
# 3                                     post    one week after HCT
# 4                                     peri   one week before HCT
#
#    timepoint_of_transplant  day_relative_to_nearest_hct alleged_abduction
# 0                      6.0                         -6.0      non_abducted
# ...

# %%
import seaborn as sns

fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

# Draw a nested barplot by species and sex
g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="disease", multiple='dodge', discrete=True, ax=ax
)

#xtick_labels = ['non abducted', 'abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Diseases across Alien Abduction', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.savefig("metadata_disease" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="hct_source", multiple='dodge', discrete=True, ax=ax
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Hct Source across Alien Abduction', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.savefig("metadata_hct_source" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="categorical_time_relative_to_engraftment", multiple='dodge', discrete=True, ax=ax
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Time across Alien Abduction', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.savefig("metadata_categorical_time" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="alleged_abduction", hue="stool_consistency", multiple='dodge', discrete=True, ax=ax
)

#xtick_labels = ['', '','','abducted','','','', 'non abducted']
#ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xlabel('Alien Abduction Status', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of Stool Consistency across Alien Abduction', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.savefig("metadata_stool_consistency" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

sns.set_theme(style="whitegrid")

g = sns.histplot(
    data=df_meta, x="week_relative_to_hct", hue="disease", multiple='dodge', discrete=True, ax=ax
)

xtick_labels = ['Two Weeks Before HCT','One Week Before HCT','HCT Week','One Week After HCT', 'Two Weeks After HCT']
ax.set_xticklabels(xtick_labels, fontsize=10);
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
ax.set_xlabel('HCT Time', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
#ax.set_title('Distribution of disease across HCT Time', fontsize=16);
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.savefig("metadata_hct_disease" + ".pdf", dpi=600, format='pdf', transparent=False, bbox_inches='tight')
# Out:
# /tmp/ipykernel_6798/806218185.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xtick_labels, fontsize=10);
# /tmp/ipykernel_6798/806218185.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
