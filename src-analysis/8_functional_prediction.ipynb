# %% [markdown]
# # Functional Prediction
#
# You can learn more about PICRUSt2 on its [GitHub wiki](https://github.com/picrust/picrust2/wiki), in [this tutorial](https://github.com/picrust/picrust2/wiki/q2-picrust2-Tutorial) and the [Nature Biotechnology article](https://doi.org/10.1038/s41587-020-0548-6).

# %% [markdown]
# <a id='setup'></a>
# ## 0. Setup

# %%
import os
import pandas as pd
import qiime2 as q2
import requests

from qiime2 import Visualization

data_dir = 'shared_data/'
    
# %matplotlib inline

# %%
def fetch_ipath(ids: list, img_output_path: str, verbose: bool = False):
    """Fetches a enriched pathways map from iPATH3 for given IDs."""
    url = 'https://pathways.embl.de/mapping.cgi'
    
    # remove colon from EC names
    if ':' in ids[0]:
        ids = [x.replace(':', '') for x in ids]
    
    if verbose:
        print(f'Fetching iPATH3 diagram for ids: {ids}')
    params = {
        'default_opacity': 0.6,
        'export_type': 'svg',
        'selection': '\n'.join(ids)
    }   
    response = requests.get(url=url, params=params)
    
    with open(img_output_path, 'wb') as img:
        img.write(response.content)

# %%
# path to the picrust2 conda environment - do not change!
picrust_env = '/opt/conda/envs/picrust2/bin'

# %% [markdown]
# <a id='picrust'></a>
# ## 1. Functional inference
#
# Use Picrust 2 to simulate metagenome data from our dataset.

# %%
# %%script env picrust_env="$picrust_env" data_dir="$data_dir" bash
#
# # append the env location to PATH so that qiime
# # can find all required executables
# export PATH=$picrust_env:$PATH
#
# $picrust_env/qiime picrust2 full-pipeline \
#     --i-seq $data_dir/Denoising/dada2_rep_set.qza \
#     --i-table $data_dir/Denoising/dada2_table.qza \
#     --output-dir $data_dir/picrust2_results \
#     --p-placement-tool sepp \
#     --p-threads 2 \
#     --p-hsp-method pic \
#     --p-max-nsti 2
# Out:
# QIIME is caching your current deployment for improved performance. This may take a few moments and should only happen once per deployment.
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/ko_metagenome.qza
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/ec_metagenome.qza
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/pathway_abundance.qza

# %%
! qiime feature-table filter-samples \
    --i-table $data_dir/picrust2_results/ko_metagenome.qza \
    --m-metadata-file $data_dir/metadata/sample_metadata.tsv \
    --p-where "[alleged_abduction]='0'" \
    --o-filtered-table $data_dir/picrust2_results/ko_metagenome_abducted.qza

! qiime feature-table filter-samples \
    --i-table $data_dir/picrust2_results/ec_metagenome.qza \
    --m-metadata-file $data_dir/metadata/sample_metadata.tsv \
    --p-where  "[alleged_abduction]='0'" \
    --o-filtered-table $data_dir/picrust2_results/ec_metagenome_abducted.qza

! qiime feature-table filter-samples \
    --i-table $data_dir/picrust2_results/pathway_abundance.qza \
    --m-metadata-file $data_dir/metadata/sample_metadata.tsv \
    --p-where  "[alleged_abduction]='0'" \
    --o-filtered-table $data_dir/picrust2_results/pathway_abundance_abducted.qza
# Out:
# QIIME is caching your current deployment for improved performance. This may take a few moments and should only happen once per deployment.
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/ko_metagenome_abducted.qza
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/ec_metagenome_abducted.qza
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/pathway_abundance_abducted.qza

# %% [markdown]
# Now, we can read in all three artifacts using QIIME 2 Python API - we can view them as DataFrames:

# %%
ko_a = q2.Artifact.load(f'{data_dir}/picrust2_results/ko_metagenome_abducted.qza').view(pd.DataFrame)
ec_a = q2.Artifact.load(f'{data_dir}/picrust2_results/ec_metagenome_abducted.qza').view(pd.DataFrame)
pa_a = q2.Artifact.load(f'{data_dir}/picrust2_results/pathway_abundance_abducted.qza').view(pd.DataFrame)

# %% [markdown]
# Let's briefly examine the contents of each of those tables:

# %%
ko_a.head(1)
# Out:
#              K00001    K00002       K00003       K00004       K00005  K00007  \
# 0KB68F  1361.400386  22.47605  6638.807061  1283.583009  2819.624601     0.0
#
#               K00008     K00009       K00010        K00011  ...    K19777  \
# 0KB68F  12651.473549  4992.0463  5519.033478  3.783984e-21  ...  0.024526
#
#         K19778  K19779  K19780      K19784  K19785  K19787  K19788    K19789  \
# 0KB68F     0.0     0.0     0.0  609.994359     0.0     0.0     0.0  0.010882
#
#          K19791
# 0KB68F  0.00029
#
# [1 rows x 10251 columns]

# %%
ec_a.head(1)
# Out:
#          EC:1.1.1.1  EC:1.1.1.10  EC:1.1.1.100  EC:1.1.1.101  EC:1.1.1.102  \
# 0KB68F  8873.981782     0.001547  11849.507136  1.572037e-19      0.034769
#
#         EC:1.1.1.103  EC:1.1.1.105  EC:1.1.1.107  EC:1.1.1.108  EC:1.1.1.11  \
# 0KB68F    958.574356  2.834738e-11      0.054358     34.422218          0.0
#
#         ...  EC:6.4.1.8   EC:6.5.1.1  EC:6.5.1.2  EC:6.5.1.3    EC:6.5.1.4  \
# 0KB68F  ...    3.210485  1998.437665  6643.33606  266.921716  9.723310e-13
#
#         EC:6.5.1.5  EC:6.5.1.6  EC:6.5.1.7  EC:6.6.1.1  EC:6.6.1.2
# 0KB68F         0.0  248.185353  248.185353  170.785566  111.015333
#
# [1 rows x 2865 columns]

# %%
pa_a.head(1)
# Out:
#          1CMET2-PWY  3-HYDROXYPHENYLACETATE-DEGRADATION-PWY  \
# 0KB68F  5609.428252                               56.803589
#
#         AEROBACTINSYN-PWY  ALL-CHORISMATE-PWY  ANAEROFRUCAT-PWY  \
# 0KB68F           0.707068                 0.0       6474.200627
#
#         ANAGLYCOLYSIS-PWY  ARG+POLYAMINE-SYN  ARGDEG-PWY  ARGORNPROST-PWY  \
# 0KB68F        8260.825591           981.9506     0.00001      1187.378324
#
#          ARGSYN-PWY  ...   THISYN-PWY  THREOCAT-PWY  THRESYN-PWY  \
# 0KB68F  5202.509647  ...  2405.565906      42.45194  5210.690347
#
#         TRNA-CHARGING-PWY   TRPSYN-PWY  TYRFUMCAT-PWY  UBISYN-PWY  \
# 0KB68F        5785.023943  4657.981644     106.453291   40.903373
#
#         UDPNAGSYN-PWY  VALDEG-PWY  VALSYN-PWY
# 0KB68F      5043.6082    2.866319  7555.79568
#
# [1 rows x 487 columns]

# %%
! qiime feature-table filter-samples \
    --i-table $data_dir/picrust2_results/ko_metagenome.qza \
    --m-metadata-file $data_dir/metadata/sample_metadata.tsv \
    --p-where "[alleged_abduction]='1'" \
    --o-filtered-table $data_dir/picrust2_results/ko_metagenome_not_abducted.qza

! qiime feature-table filter-samples \
    --i-table $data_dir/picrust2_results/ec_metagenome.qza \
    --m-metadata-file $data_dir/metadata/sample_metadata.tsv \
    --p-where  "[alleged_abduction]='1'" \
    --o-filtered-table $data_dir/picrust2_results/ec_metagenome_not_abducted.qza

! qiime feature-table filter-samples \
    --i-table $data_dir/picrust2_results/pathway_abundance.qza \
    --m-metadata-file $data_dir/metadata/sample_metadata.tsv \
    --p-where  "[alleged_abduction]='1'" \
    --o-filtered-table $data_dir/picrust2_results/pathway_abundance_not_abducted.qza
# Out:
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/ko_metagenome_not_abducted.qza
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/ec_metagenome_not_abducted.qza
# Saved FeatureTable[Frequency] to: shared_data//picrust2_results/pathway_abundance_not_abducted.qza

# %%
ko_na = q2.Artifact.load(f'{data_dir}/picrust2_results/ko_metagenome_not_abducted.qza').view(pd.DataFrame)
ec_na = q2.Artifact.load(f'{data_dir}/picrust2_results/ec_metagenome_not_abducted.qza').view(pd.DataFrame)
pa_na = q2.Artifact.load(f'{data_dir}/picrust2_results/pathway_abundance_not_abducted.qza').view(pd.DataFrame)

# %%
ko_na.head(1)
# Out:
#               K00001    K00002        K00003        K00004        K00005  \
# 0DOSLC  54182.069959  6.981562  114120.68968  72354.209497  45604.268712
#
#            K00007        K00008        K00009        K00010    K00011  ...  \
# 0DOSLC  10.652446  79362.866673  59942.895952  33794.194597  0.000005  ...
#
#            K19776     K19777     K19778    K19779     K19780        K19784  \
# 0DOSLC  25.698715  37.359132  22.442708  5.201112  19.893207  27133.128495
#
#           K19785  K19788     K19789  K19791
# 0DOSLC  0.007928     0.0  37.851223     0.0
#
# [1 rows x 9847 columns]

# %%
ec_na.head(1)
# Out:
#            EC:1.1.1.1   EC:1.1.1.10  EC:1.1.1.100  EC:1.1.1.101  EC:1.1.1.102  \
# 0DOSLC  279428.793373  1.404367e-09   333782.8077  3.742706e-17      0.064341
#
#         EC:1.1.1.103  EC:1.1.1.105  EC:1.1.1.107  EC:1.1.1.108  EC:1.1.1.11  \
# 0DOSLC    624.524986      2.125909      0.112491   7238.304061    10.652446
#
#         ...  EC:6.4.1.8   EC:6.5.1.1     EC:6.5.1.2   EC:6.5.1.3  EC:6.5.1.4  \
# 0DOSLC  ...    3.295559  2392.831915  136766.045596  6958.754988   34.220674
#
#         EC:6.5.1.5  EC:6.5.1.6  EC:6.5.1.7   EC:6.6.1.1  EC:6.6.1.2
# 0DOSLC    0.002587  941.460175  941.460175  1173.472589  633.545709
#
# [1 rows x 2787 columns]

# %%
pa_na.head(1)
# Out:
#           1CMET2-PWY  3-HYDROXYPHENYLACETATE-DEGRADATION-PWY  \
# 0DOSLC  63771.529103                             3814.332432
#
#         AEROBACTINSYN-PWY  ALL-CHORISMATE-PWY  ANAEROFRUCAT-PWY  \
# 0DOSLC          269.19087          364.005719     155715.806612
#
#         ANAGLYCOLYSIS-PWY  ARG+POLYAMINE-SYN  ARGDEG-PWY  ARGORNPROST-PWY  \
# 0DOSLC      154301.035122       13280.963268   61.024873     91538.094937
#
#           ARGSYN-PWY  ...   THISYN-PWY  THREOCAT-PWY    THRESYN-PWY  \
# 0DOSLC  81425.820836  ...  4605.343494    906.927598  124580.518839
#
#         TRNA-CHARGING-PWY    TRPSYN-PWY  TYRFUMCAT-PWY  UBISYN-PWY  \
# 0DOSLC       37532.251923  83719.081706     346.681116   169.56297
#
#         UDPNAGSYN-PWY  VALDEG-PWY     VALSYN-PWY
# 0DOSLC   136811.33978  827.124515  133300.743599
#
# [1 rows x 485 columns]

# %% [markdown]
# You can see that they look just like the other feature tables we worked before with. The difference is that now they do not contain information about ASVs but about different levels of the functional profiles:
#
# 1. `ko` table: columns represent KEGG orthologs, as indicated by their names (e.g., **K**19777)
# 2. `ec` table: columns represent enzymes, as indicated by the Enzyme Commission numbers (e.g., **EC**:1.1.1.108)
# 3. `pa` table: columns represent entire pathways using the MetaCyc classification (e.g., ANAGLYCOLYSIS-PWY)

# %% [markdown]
# <a id='ipath'></a>
# ### 1.1 Enriched KEGG orthologs visualization
#
# We start by merging our feature table with the treatment column (`disease`) from the metadata:

# %%
metadata = pd.read_csv(f'{data_dir}/metadata/sample_metadata.tsv', sep='\t', header=0, index_col=0)

# %%
ko_a_meta = ko_a.merge(metadata[['disease']], left_index=True, right_index=True)
ec_a_meta = ec_a.merge(metadata[['disease']], left_index=True, right_index=True)
pa_a_meta = pa_a.merge(metadata[['disease']], left_index=True, right_index=True)

# %%
ko_na_meta = ko_na.merge(metadata[['disease']], left_index=True, right_index=True)
ec_na_meta = ec_na.merge(metadata[['disease']], left_index=True, right_index=True)
pa_na_meta = pa_na.merge(metadata[['disease']], left_index=True, right_index=True)
pa_na_meta
# Out:
#            1CMET2-PWY  3-HYDROXYPHENYLACETATE-DEGRADATION-PWY  \
# 0DOSLC   63771.529103                             3814.332432
# 0WG67D   52492.246729                             2795.283692
# 12H3HH    1566.689152                              110.771443
# 12QINS    2060.699133                              175.132817
# 12ZW3B    3868.513776                              425.091009
# 2I7SIQ   19394.299131                              124.559846
# 3ALGNE   72163.990120                             6924.010171
# 3XK7UB  151843.310887                               31.047374
# 4O2DTB   42562.792364                             1159.286797
# 5Y49IM     226.034828                                0.000000
# 7FXIF8    4398.893888                              103.580090
# 8BSFV2     516.921537                               22.589999
# 8ETYA3  109450.243313                            73058.094295
# 8HNX4O     392.188285                                8.335853
# 9MD25S   24470.699099                                5.047877
# A107EY   56160.013180                               15.676191
# FSX8UT   80902.047538                            25111.100254
# G7D1L0    3866.445632                                0.860244
# LCG2LJ    2098.319986                              206.146766
# M12Q6E   42485.462649                              864.096703
# PCUMU7    4314.351351                              305.288657
# Q4TOSG    3664.393110                                0.000000
# RR9BC4     477.307058                                0.000000
# T41N7M   67517.555499                             4571.404180
# VGQSRI    1337.041614                              125.252010
# Z2DXHY     277.183788                               31.585880
#
#         AEROBACTINSYN-PWY  ALL-CHORISMATE-PWY  ANAEROFRUCAT-PWY  \
# 0DOSLC         269.190870          364.005719     155715.806612
# 0WG67D         105.305417          338.491398     113991.857189
# 12H3HH           0.767530           34.983111       3552.142687
# 12QINS          11.689512           57.304979       5544.819708
# 12ZW3B           1.102942           38.113477       6545.144276
# 2I7SIQ           0.908484           48.410651      19322.252386
# 3ALGNE          25.053797         1375.161327     147792.962064
# 3XK7UB           0.182697          227.161183     112025.255066
# 4O2DTB          13.526408          135.525619      56277.975900
# 5Y49IM           0.000000            0.000000        163.591971
# 7FXIF8           2.846160            0.000000       6039.241226
# 8BSFV2           0.000000            0.000000        928.556150
# 8ETYA3        1134.417141        38599.475298     104229.496257
# 8HNX4O           0.000000           18.084243       1066.792153
# 9MD25S           0.005512            0.000000      25125.216779
# A107EY           0.264133           82.664301       2386.318222
# FSX8UT       14050.778187        63089.816326     125889.289393
# G7D1L0           0.002032          127.415970       4177.689237
# LCG2LJ           0.967729          240.040426       5832.302569
# M12Q6E         459.858644         3086.112382      16521.682461
# PCUMU7           1.170346           31.754621       7051.712516
# Q4TOSG           0.000000            0.000000       5598.846816
# RR9BC4           0.000000            0.000000        363.659875
# T41N7M          13.922772          287.077730      93870.538430
# VGQSRI           0.745149            0.000000       4231.369666
# Z2DXHY           0.000000            0.000000        794.685024
#
#         ANAGLYCOLYSIS-PWY  ARG+POLYAMINE-SYN    ARGDEG-PWY  ARGORNPROST-PWY  \
# 0DOSLC      154301.035122       13280.963268     61.024873     91538.094937
# 0WG67D      112345.430911       12578.289060     30.875975     60516.674666
# 12H3HH        3526.986493         357.652313      7.425243      1856.630077
# 12QINS        5496.283499         354.548907     24.761137      2892.589270
# 12ZW3B        6729.880382         644.145772      9.661871      3444.566857
# 2I7SIQ       27949.875576         711.345531     11.195332      1806.322880
# 3ALGNE      146559.785462       24148.140499    203.768629     83572.429933
# 3XK7UB      237342.722003       33551.080042      6.582473      8950.105125
# 4O2DTB       60056.338809        2750.558217     27.523162     23483.176504
# 5Y49IM         300.307783           0.000000      0.000000        88.830622
# 7FXIF8        6642.641739         394.617566      0.000072      1967.785893
# 8BSFV2         943.035257          44.027708      0.000000       439.866770
# 8ETYA3      112381.212870       77557.255946   4444.515948    103247.161004
# 8HNX4O        1042.987283         158.720807      6.918396       164.396550
# 9MD25S       39180.612597        5267.993423      0.000000      1176.559488
# A107EY       56413.595508         128.791033     17.031565       271.727324
# FSX8UT      127862.829781       62807.666328  41840.505769     67129.501937
# G7D1L0        5019.381034         736.826810      7.225544        57.587192
# LCG2LJ        5829.580244         670.262546     87.699730      3138.764659
# M12Q6E       44396.427840        2411.114775   1637.173916      2216.609938
# PCUMU7        7569.088491         999.906928      7.311312      2588.937899
# Q4TOSG        8351.513944           0.000000      0.000000        28.119596
# RR9BC4         717.964918          15.321689      0.000000        18.344639
# T41N7M      102954.883723        5974.839574     79.008444     37913.794226
# VGQSRI        4198.720262         240.105175      0.000000      2252.082842
# Z2DXHY         788.993592          50.196845      0.000000       421.045827
#
#            ARGSYN-PWY  ...  THREOCAT-PWY    THRESYN-PWY  TRNA-CHARGING-PWY  \
# 0DOSLC   81425.820836  ...    906.927598  124580.518839       37532.251923
# 0WG67D   56468.060640  ...    684.908222   90862.382544       60499.276466
# 12H3HH    1681.829836  ...     40.238435    2793.299811        1712.015878
# 12QINS    2497.139474  ...     67.339397    4290.651443        1776.600557
# 12ZW3B    3374.395233  ...     47.244421    4803.305543        3774.292469
# 2I7SIQ   19968.557918  ...     82.546401   19703.582448       21117.382137
# 3ALGNE   74357.220212  ...   8139.067716  119627.861507       92460.408598
# 3XK7UB  145502.869853  ...    141.270223  152388.168749      161176.774858
# 4O2DTB   40299.157407  ...    292.486264   51198.201852       12236.252544
# 5Y49IM     208.889126  ...      0.000000     219.624662         214.850580
# 7FXIF8    3764.340325  ...     24.054524    4972.256232        5171.666036
# 8BSFV2     523.578803  ...      5.544651     757.970515         287.006292
# 8ETYA3  109412.078280  ...   3472.378567  125250.302540      108744.073397
# 8HNX4O     479.794315  ...     16.614756    1045.217125         820.293293
# 9MD25S   25672.773682  ...      0.299606   28661.610192       29455.398190
# A107EY   57313.821877  ...     28.042683   56200.271523        1792.187283
# FSX8UT   80659.287287  ...  41297.903025  109731.672873       98908.431332
# G7D1L0    3537.848118  ...      0.112804    4352.741988        3985.410415
# LCG2LJ    2504.798696  ...    230.569156    4594.808023        3380.000838
# M12Q6E   43174.928143  ...   1372.546730   42802.903098       28873.829793
# PCUMU7    3663.988760  ...     89.965974    5764.685101        4613.934888
# Q4TOSG    5051.817137  ...      0.000000    6108.471542        6047.609136
# RR9BC4     535.551572  ...      0.000000     499.775601         519.543623
# T41N7M   57937.180208  ...    593.485045   78232.574755       69258.228891
# VGQSRI    1823.815529  ...     32.863340    3272.280161        1598.700672
# Z2DXHY     348.831600  ...      6.643024     616.159806         295.049516
#
#            TRPSYN-PWY  TYRFUMCAT-PWY    UBISYN-PWY  UDPNAGSYN-PWY  VALDEG-PWY  \
# 0DOSLC   83719.081706   3.466811e+02    169.562970  136811.339780  827.124515
# 0WG67D   59714.134335   9.816188e+02    352.867520   98470.856591  629.269301
# 12H3HH    1674.888760   8.938007e+01     12.636895    3051.311752   20.697951
# 12QINS    2395.907599   2.191305e+00     19.414488    4746.855952   35.427232
# 12ZW3B    2948.429096   8.150358e+01     19.437793    5362.348110   35.353132
# 2I7SIQ   10994.016597   6.568585e+01     16.604471   12371.755710    7.279785
# 3ALGNE   70873.290765   8.975149e+03    681.628084  128839.670201  833.387263
# 3XK7UB  126910.533547   1.891976e+03   2156.938144  150424.571548    0.298001
# 4O2DTB   39679.014390   1.990093e+01     57.912956   54505.856787  261.043490
# 5Y49IM     177.283190   0.000000e+00      0.000000      32.583888    0.000000
# 7FXIF8    3670.973483   3.025189e+01      4.210353    4452.862275   20.008273
# 8BSFV2     497.331246   1.909055e-05      0.000008     832.736814    5.141002
# 8ETYA3   98213.253772   7.019896e+04  69047.281092  121690.466189  411.325704
# 8HNX4O     369.160372   3.082976e-07      5.896273     984.172655    0.236700
# 9MD25S   23479.033072   1.606365e+01     95.223636   22174.373045   15.564095
# A107EY   62155.984889   1.103392e+01     50.761855   56249.091838    0.836831
# FSX8UT   77296.968899   1.816844e+01  35786.782675  108526.622122  541.063714
# G7D1L0    2723.671352   4.685587e+00    123.384451    2895.032497    0.084286
# LCG2LJ    2428.987154   9.811003e+01     84.952977    5031.839784   35.575251
# M12Q6E   46079.973418   5.369342e+02   1363.540412   42289.663817    0.743029
# PCUMU7    3399.288498   6.258225e+01     12.274577    5970.841605   26.904696
# Q4TOSG    3954.873567   0.000000e+00      0.000000    6531.384339    0.000000
# RR9BC4     474.872678   0.000000e+00      0.000013     276.827166    0.096400
# T41N7M   49137.698565   4.768262e+01    103.832418   87098.085876  422.476535
# VGQSRI    1794.068478   1.084402e+01      0.000053    3643.065493   27.852241
# Z2DXHY     346.637603   5.905161e-06      0.000008     687.330191    5.206792
#
#            VALSYN-PWY                    disease
# 0DOSLC  133300.743599                   Leukemia
# 0WG67D   95092.619082                   Leukemia
# 12H3HH    3015.677060     Non-Hodgkin's Lymphoma
# 12QINS    4264.080373                   Leukemia
# 12ZW3B    6197.975063                   Leukemia
# 2I7SIQ   24151.867648                   Leukemia
# 3ALGNE  136162.915136                   Leukemia
# 3XK7UB  205174.804929     Non-Hodgkin's Lymphoma
# 4O2DTB   66423.855353                   Leukemia
# 5Y49IM     274.984545                   Leukemia
# 7FXIF8    8032.185049                   Leukemia
# 8BSFV2     881.639802     Non-Hodgkin's Lymphoma
# 8ETYA3  127204.554953                   Leukemia
# 8HNX4O     557.633685                   Leukemia
# 9MD25S   34029.040869                   Leukemia
# A107EY   79240.641493     Non-Hodgkin's Lymphoma
# FSX8UT  112648.122833                   Leukemia
# G7D1L0    4754.868357                   Leukemia
# LCG2LJ    4388.465558                   Leukemia
# M12Q6E   58880.829111          Hodgkin's Disease
# PCUMU7    5160.857889                   Leukemia
# Q4TOSG    9099.813351  Myelodysplastic Syndromes
# RR9BC4     737.384008     Non-Hodgkin's Lymphoma
# T41N7M   85738.945035                   Leukemia
# VGQSRI    3141.104727                   Leukemia
# Z2DXHY     582.499595                   Leukemia
#
# [26 rows x 486 columns]

# %% [markdown]
# Next, we will calculate an average abundance of each KO, EC and pathway in each group (treatment vs. no treatment):

# %%
# collapse samples per sample_type - calculate average abundance

ko_a_meta_avg = ko_a_meta.groupby('disease').mean()
ec_a_meta_avg = ec_a_meta.groupby('disease').mean()
pa_a_meta_avg = pa_a_meta.groupby('disease').mean()
ko_na_meta_avg = ko_na_meta.groupby('disease').mean()
ec_na_meta_avg = ec_na_meta.groupby('disease').mean()
pa_na_meta_avg = pa_na_meta.groupby('disease').mean()

# %%
ko_a_meta_avg
# Out:
#                                  K00001       K00002        K00003  \
# disease
# Hodgkin's Disease          19028.235594  1065.362017  34387.092140
# Leukemia                   17227.619162   423.810503  16639.077543
# Myelodysplastic Syndromes  13056.800498  1193.270974  14331.828948
# Non-Hodgkin's Lymphoma     11439.378480   578.621286  26721.551141
#
#                                 K00004        K00005     K00007        K00008  \
# disease
# Hodgkin's Disease          5062.437658  14231.673873   0.909434  41327.780462
# Leukemia                   2499.003063   6982.468350  21.041076  18481.732069
# Myelodysplastic Syndromes   360.672058  22843.442305   0.000000  28629.955610
# Non-Hodgkin's Lymphoma     3549.133715  21085.984097   1.041146  40508.693863
#
#                                  K00009        K00010    K00011  ...  \
# disease                                                          ...
# Hodgkin's Disease           8815.128883  16317.379247  0.002319  ...
# Leukemia                   11486.349201   9974.081115  0.003699  ...
# Myelodysplastic Syndromes   3001.358000   8689.148528  0.101260  ...
# Non-Hodgkin's Lymphoma     26224.881159  12625.656417  0.048428  ...
#
#                                K19777      K19778     K19779      K19780  \
# disease
# Hodgkin's Disease          357.612024  374.245338  82.476389  357.136535
# Leukemia                    38.012421  371.852232   8.854783   35.672199
# Myelodysplastic Syndromes    0.000000    0.180566   0.000000    0.000000
# Non-Hodgkin's Lymphoma     352.133688  354.083430  87.898479  351.837638
#
#                                 K19784    K19785    K19787        K19788  \
# disease
# Hodgkin's Disease          1636.803313  0.000000  0.000000  0.000000e+00
# Leukemia                   5126.323039  0.000112  0.000287  1.960334e-65
# Myelodysplastic Syndromes   220.871235  0.000000  0.000000  0.000000e+00
# Non-Hodgkin's Lymphoma     4058.661470  0.000130  0.000000  8.615288e-62
#
#                                 K19789    K19791
# disease
# Hodgkin's Disease           764.903179  0.004102
# Leukemia                    190.707274  0.002403
# Myelodysplastic Syndromes  1450.629391  0.000000
# Non-Hodgkin's Lymphoma      505.411611  0.001922
#
# [4 rows x 10251 columns]

# %%
ec_a_meta_avg
# Out:
#                              EC:1.1.1.1  EC:1.1.1.10  EC:1.1.1.100  \
# disease
# Hodgkin's Disease          59201.622706     1.936135  84269.563776
# Leukemia                   42676.254918     1.486460  59547.867017
# Myelodysplastic Syndromes  21570.018224     0.930931  76914.138717
# Non-Hodgkin's Lymphoma     47317.641787     3.671824  73667.712361
#
#                            EC:1.1.1.101  EC:1.1.1.102  EC:1.1.1.103  \
# disease
# Hodgkin's Disease          1.420883e-19      0.492604   9563.472670
# Leukemia                   6.923548e-19      4.797126   1508.774920
# Myelodysplastic Syndromes  6.164715e-21      0.000010   7444.313042
# Non-Hodgkin's Lymphoma     9.768580e-19      0.132309   3453.161945
#
#                            EC:1.1.1.105  EC:1.1.1.107  EC:1.1.1.108  \
# disease
# Hodgkin's Disease          4.016185e-10      1.398176    204.295806
# Leukemia                   4.480973e-01      0.850152    201.423154
# Myelodysplastic Syndromes  0.000000e+00      0.361765   3975.211256
# Non-Hodgkin's Lymphoma     8.812602e-02      2.626358   1960.874303
#
#                            EC:1.1.1.11  ...  EC:6.4.1.8   EC:6.5.1.1  \
# disease                                 ...
# Hodgkin's Disease             0.909434  ...   30.085516  6494.472966
# Leukemia                     21.041076  ...    4.553000  3345.707116
# Myelodysplastic Syndromes     0.000000  ...    0.000000  3237.279340
# Non-Hodgkin's Lymphoma        1.041146  ...   98.219080  8831.497716
#
#                              EC:6.5.1.2   EC:6.5.1.3  EC:6.5.1.4  \
# disease
# Hodgkin's Disease          45453.742876  4127.304980  371.255156
# Leukemia                   24506.126360  2459.493577  362.636418
# Myelodysplastic Syndromes  34037.845491  3234.305450    0.641981
# Non-Hodgkin's Lymphoma     34687.161603  3556.853184  454.378820
#
#                              EC:6.5.1.5   EC:6.5.1.6   EC:6.5.1.7  \
# disease
# Hodgkin's Disease          4.711116e-93  1369.242137  1369.242137
# Leukemia                   6.425743e-05   510.747908   510.747908
# Myelodysplastic Syndromes  0.000000e+00   338.171783   338.171783
# Non-Hodgkin's Lymphoma     5.192716e-05  1349.660664  1349.660664
#
#                             EC:6.6.1.1    EC:6.6.1.2
# disease
# Hodgkin's Disease          3375.390229   2979.604866
# Leukemia                   1154.913759   1857.370608
# Myelodysplastic Syndromes  6838.272213  12205.136175
# Non-Hodgkin's Lymphoma     5263.938253   4059.135492
#
# [4 rows x 2865 columns]

# %%
pa_a_meta_avg
# Out:
#                              1CMET2-PWY  \
# disease
# Hodgkin's Disease          31162.419166
# Leukemia                   14474.596924
# Myelodysplastic Syndromes  27539.507557
# Non-Hodgkin's Lymphoma     23344.962993
#
#                            3-HYDROXYPHENYLACETATE-DEGRADATION-PWY  \
# disease
# Hodgkin's Disease                                      236.455288
# Leukemia                                               228.825864
# Myelodysplastic Syndromes                               10.199690
# Non-Hodgkin's Lymphoma                                 255.005188
#
#                            AEROBACTINSYN-PWY  ALL-CHORISMATE-PWY  \
# disease
# Hodgkin's Disease                   5.834883         1765.841533
# Leukemia                           98.334934          690.832831
# Myelodysplastic Syndromes           2.598471          100.701889
# Non-Hodgkin's Lymphoma              7.088741         1103.823229
#
#                            ANAEROFRUCAT-PWY  ANAGLYCOLYSIS-PWY  \
# disease
# Hodgkin's Disease              28808.684822       41706.153740
# Leukemia                       22961.374273       26294.150322
# Myelodysplastic Syndromes      28461.994549       37301.772122
# Non-Hodgkin's Lymphoma         28260.608367       35310.414158
#
#                            ARG+POLYAMINE-SYN  ARGDEG-PWY  ARGORNPROST-PWY  \
# disease
# Hodgkin's Disease                5869.759793  691.860993      5122.506043
# Leukemia                         3087.242212  261.658230      4693.925958
# Myelodysplastic Syndromes        6832.735976    6.832042      5473.324694
# Non-Hodgkin's Lymphoma           6211.704743  566.729025      7420.252549
#
#                              ARGSYN-PWY  ...    THISYN-PWY  THREOCAT-PWY  \
# disease                                  ...
# Hodgkin's Disease          31287.629600  ...  17824.192086    350.323012
# Leukemia                   14788.007768  ...   6551.055647    406.654119
# Myelodysplastic Syndromes  21181.456474  ...  21293.844391     30.957010
# Non-Hodgkin's Lymphoma     23448.637803  ...   8995.458905    678.610439
#
#                             THRESYN-PWY  TRNA-CHARGING-PWY    TRPSYN-PWY  \
# disease
# Hodgkin's Disease          30792.296334       32061.643846  29981.198004
# Leukemia                   17005.916606       15561.742897  13460.415022
# Myelodysplastic Syndromes  30566.034246       28779.619168  19231.325066
# Non-Hodgkin's Lymphoma     27794.143991       25098.281772  18179.796477
#
#                            TYRFUMCAT-PWY   UBISYN-PWY  UDPNAGSYN-PWY  \
# disease
# Hodgkin's Disease             654.706874  1455.220730   18286.029379
# Leukemia                      241.475892  1396.212503   18221.914383
# Myelodysplastic Syndromes     212.058219   642.385398   16477.394555
# Non-Hodgkin's Lymphoma        502.104125   949.595462   24969.884756
#
#                            VALDEG-PWY    VALSYN-PWY
# disease
# Hodgkin's Disease          161.726056  44546.328173
# Leukemia                    69.064722  20282.531193
# Myelodysplastic Syndromes    0.138583  35292.947268
# Non-Hodgkin's Lymphoma      30.244374  31692.309386
#
# [4 rows x 487 columns]

# %%
ko_na_meta_avg
# Out:
#                                  K00001     K00002        K00003  \
# disease
# Hodgkin's Disease          34953.468700   2.552380  41150.899491
# Leukemia                   12857.970171  87.614986  36454.100688
# Myelodysplastic Syndromes   1994.688516   0.000000   6361.559141
# Non-Hodgkin's Lymphoma     16468.199466  76.265046  41743.571134
#
#                                  K00004        K00005     K00007  \
# disease
# Hodgkin's Disease           4825.747676   6031.352334   2.987571
# Leukemia                   25317.228261  17271.679642  12.264023
# Myelodysplastic Syndromes      0.374649   3321.432803   0.000000
# Non-Hodgkin's Lymphoma      4283.070794  15978.635289   0.000000
#
#                                  K00008        K00009        K00010  \
# disease
# Hodgkin's Disease           2319.676886   1318.989544   6554.637510
# Leukemia                   26162.447626  23579.801853  13815.782371
# Myelodysplastic Syndromes  19096.681963  25235.315634      8.007399
# Non-Hodgkin's Lymphoma     53992.016472  63361.706906   1237.352134
#
#                                  K00011  ...       K19776      K19777  \
# disease                                  ...
# Hodgkin's Disease          1.033848e-21  ...   516.795292   60.329399
# Leukemia                   7.105095e-04  ...  1459.920138  671.360458
# Myelodysplastic Syndromes  0.000000e+00  ...     0.000000    0.000000
# Non-Hodgkin's Lymphoma     1.927133e-21  ...     2.694251    2.572491
#
#                                K19778      K19779      K19780        K19784  \
# disease
# Hodgkin's Disease          242.171153   14.429723   57.305988   1022.062706
# Leukemia                   696.323734  146.345722  601.635315  12723.246532
# Myelodysplastic Syndromes    0.000000    0.000000    0.000000   3297.361743
# Non-Hodgkin's Lymphoma       3.047133    0.639329    2.559274   7232.517849
#
#                              K19785        K19788       K19789    K19791
# disease
# Hodgkin's Disease          0.000000  0.000000e+00  1147.702727  0.422670
# Leukemia                   0.010643  3.690182e-59  1491.308203  0.000295
# Myelodysplastic Syndromes  0.000000  0.000000e+00    40.445930  0.000000
# Non-Hodgkin's Lymphoma     0.000000  0.000000e+00   147.295410  0.006617
#
# [4 rows x 9847 columns]

# %%
ec_na_meta_avg
# Out:
#                               EC:1.1.1.1  EC:1.1.1.10   EC:1.1.1.100  \
# disease
# Hodgkin's Disease          231499.446004     0.000002   53734.031499
# Leukemia                    82104.480065     0.271120  124752.655966
# Myelodysplastic Syndromes    3918.127866     0.000000    9123.134872
# Non-Hodgkin's Lymphoma      87493.464370     0.550642   73266.077860
#
#                            EC:1.1.1.101  EC:1.1.1.102  EC:1.1.1.103  \
# disease
# Hodgkin's Disease          4.042741e-20      1.012892   1244.272780
# Leukemia                   1.000640e-17      0.333364   2603.384905
# Myelodysplastic Syndromes  0.000000e+00      0.000000      0.000000
# Non-Hodgkin's Lymphoma     2.841071e-19      0.017707   3856.331836
#
#                            EC:1.1.1.105  EC:1.1.1.107  EC:1.1.1.108  \
# disease
# Hodgkin's Disease          4.558188e-02     41.374385    111.707630
# Leukemia                   2.769499e-01      0.086174   4841.721009
# Myelodysplastic Syndromes  0.000000e+00      0.000000      0.000000
# Non-Hodgkin's Lymphoma     1.443694e-11      0.245620     91.187411
#
#                            EC:1.1.1.11  ...  EC:6.4.1.8    EC:6.5.1.1  \
# disease                                 ...
# Hodgkin's Disease             2.987571  ...   21.852330   1718.308313
# Leukemia                     12.264023  ...    1.874056   7091.477817
# Myelodysplastic Syndromes     0.000000  ...    0.000000   3291.160000
# Non-Hodgkin's Lymphoma        0.000000  ...   13.319997  12216.842675
#
#                              EC:6.5.1.2   EC:6.5.1.3   EC:6.5.1.4  \
# disease
# Hodgkin's Disease          43140.181236  2953.253153    60.367298
# Leukemia                   44897.114723  9195.087383  3605.289367
# Myelodysplastic Syndromes   6431.549308     0.000000     0.000000
# Non-Hodgkin's Lymphoma     42925.781427   295.685416     4.284694
#
#                               EC:6.5.1.5  EC:6.5.1.6  EC:6.5.1.7   EC:6.6.1.1  \
# disease
# Hodgkin's Disease          3.358344e-124  359.114744  359.114744  1102.277545
# Leukemia                    8.241254e-03  747.180949  747.180949  6465.561181
# Myelodysplastic Syndromes   0.000000e+00    0.000000    0.000000   240.104360
# Non-Hodgkin's Lymphoma      0.000000e+00  294.224634  294.224634   664.838419
#
#                             EC:6.6.1.2
# disease
# Hodgkin's Disease          1131.022601
# Leukemia                   7710.808756
# Myelodysplastic Syndromes   198.473166
# Non-Hodgkin's Lymphoma      482.420288
#
# [4 rows x 2787 columns]

# %%
pa_na_meta_avg
# Out:
#                              1CMET2-PWY  \
# disease
# Hodgkin's Disease          42485.462649
# Leukemia                   29240.267115
# Myelodysplastic Syndromes   3664.393110
# Non-Hodgkin's Lymphoma     42112.848363
#
#                            3-HYDROXYPHENYLACETATE-DEGRADATION-PWY  \
# disease
# Hodgkin's Disease                                      864.096703
# Leukemia                                              6260.231204
# Myelodysplastic Syndromes                                0.000000
# Non-Hodgkin's Lymphoma                                  36.017001
#
#                            AEROBACTINSYN-PWY  ALL-CHORISMATE-PWY  \
# disease
# Hodgkin's Disease                 459.858644         3086.112382
# Leukemia                          822.717498         5513.193568
# Myelodysplastic Syndromes           0.000000            0.000000
# Non-Hodgkin's Lymphoma              0.242872           68.961719
#
#                            ANAEROFRUCAT-PWY  ANAGLYCOLYSIS-PWY  \
# disease
# Hodgkin's Disease              16521.682461       44396.427840
# Leukemia                       46508.565440       48800.519429
# Myelodysplastic Syndromes       5598.846816        8351.513944
# Non-Hodgkin's Lymphoma         23851.186400       59788.860836
#
#                            ARG+POLYAMINE-SYN   ARGDEG-PWY  ARGORNPROST-PWY  \
# disease
# Hodgkin's Disease                2411.114775  1637.173916      2216.609938
# Leukemia                        11017.178063  2465.368221     25652.647536
# Myelodysplastic Syndromes           0.000000     0.000000        28.119596
# Non-Hodgkin's Lymphoma           6819.374557     6.207856      2307.334787
#
#                              ARGSYN-PWY  ...    THISYN-PWY  THREOCAT-PWY  \
# disease                                  ...
# Hodgkin's Disease          43174.928143  ...   4788.809612   1372.546730
# Leukemia                   29915.998824  ...  10236.472859   2946.600518
# Myelodysplastic Syndromes   5051.817137  ...    161.837161      0.000000
# Non-Hodgkin's Lymphoma     41111.530388  ...  10085.182092     43.019198
#
#                             THRESYN-PWY  TRNA-CHARGING-PWY    TRPSYN-PWY  \
# disease
# Hodgkin's Disease          42802.903098       28873.829793  46079.973418
# Leukemia                   41146.338823       29254.868565  28071.626259
# Myelodysplastic Syndromes   6108.471542        6047.609136   3954.873567
# Non-Hodgkin's Lymphoma     42527.897240       33097.505587  38342.722224
#
#                            TYRFUMCAT-PWY   UBISYN-PWY  UDPNAGSYN-PWY  \
# disease
# Hodgkin's Disease             536.934202  1363.540412   42289.663817
# Leukemia                     4261.056857  5609.540358   42331.366250
# Myelodysplastic Syndromes       0.000000     0.000000    6531.384339
# Non-Hodgkin's Lymphoma        398.477999   444.067383   42166.907824
#
#                            VALDEG-PWY    VALSYN-PWY
# disease
# Hodgkin's Disease            0.743029  58880.829111
# Leukemia                   217.641211  44847.753650
# Myelodysplastic Syndromes    0.000000   9099.813351
# Non-Hodgkin's Lymphoma       5.414037  57810.029458
#
# [4 rows x 485 columns]

# %% [markdown]
# ### 1.2 Enriched pathways

# %%
! qiime composition add-pseudocount \
    --i-table $data_dir/picrust2_results/pathway_abundance.qza \
    --o-composition-table $data_dir/picrust2_results/pathway_abundance_abund.qza
# Out:
# Saved FeatureTable[Composition] to: shared_data//picrust2_results/pathway_abundance_abund.qza

# %%
! qiime composition ancom \
    --i-table $data_dir/picrust2_results/pathway_abundance_abund.qza \
    --m-metadata-file $data_dir/metadata/str_metadata.tsv \
    --m-metadata-column alleged_abduction \
    --p-transform-function log \
    --o-visualization $data_dir/pa_ancom_abducted.qzv
# Out:
# Saved Visualization to: shared_data//pa_ancom_abducted.qzv

# %%
Visualization.load(f'{data_dir}/pa_ancom_abducted.qzv')
# Out:
# <visualization: Visualization uuid: 3ecaa91a-5bbe-49a2-8487-854e36ab79fb>

# %%
! qiime composition add-pseudocount \
    --i-table $data_dir/picrust2_results/pathway_abundance_abducted.qza \
    --o-composition-table $data_dir/picrust2_results/pathway_abundance_abducted_abund.qza

! qiime composition add-pseudocount \
    --i-table $data_dir/picrust2_results/pathway_abundance_not_abducted.qza \
    --o-composition-table $data_dir/picrust2_results/pathway_abundance_not_abducted_abund.qza
# Out:
# Saved FeatureTable[Composition] to: shared_data//picrust2_results/pathway_abundance_abducted_abund.qza
# Saved FeatureTable[Composition] to: shared_data//picrust2_results/pathway_abundance_not_abducted_abund.qza

# %%
! qiime composition ancom \
    --i-table $data_dir/picrust2_results/pathway_abundance_abducted_abund.qza \
    --m-metadata-file $data_dir/metadata/str_nan_metadata.tsv \
    --m-metadata-column disease \
    --p-transform-function log \
    --o-visualization $data_dir/pa_ancom_abducted_disease.qzv

! qiime composition ancom \
    --i-table $data_dir/picrust2_results/pathway_abundance_not_abducted_abund.qza \
    --m-metadata-file $data_dir/metadata/str_nan_metadata.tsv \
    --m-metadata-column disease \
    --p-transform-function log \
    --o-visualization $data_dir/pa_ancom_not_abducted_disease.qzv

# %%
Visualization.load(f'{data_dir}/pa_ancom_abducted_disease.qzv')
# Out:
# <visualization: Visualization uuid: 9dea16bc-3a8a-47f5-aeb4-2d89f24d29ed>

# %%
Visualization.load(f'{data_dir}/pa_ancom_not_abducted_disease.qzv')
# Out:
# <visualization: Visualization uuid: a7b5f9fe-a713-41af-8b59-f38178d5af0d>

# %% [markdown]
# ## 2. Functional Inference on Stool Consistency

# %%
metadata = pd.read_csv(f'{data_dir}/metadata/str_metadata.tsv', sep='\t', header=0, index_col=0)

# %%
ko_a_meta = ko_a.merge(metadata[['stool_consistency']], left_index=True, right_index=True)
ec_a_meta = ec_a.merge(metadata[['stool_consistency']], left_index=True, right_index=True)
pa_a_meta = pa_a.merge(metadata[['stool_consistency']], left_index=True, right_index=True)
ko_na_meta = ko_na.merge(metadata[['stool_consistency']], left_index=True, right_index=True)
ec_na_meta = ec_na.merge(metadata[['stool_consistency']], left_index=True, right_index=True)
pa_na_meta = pa_na.merge(metadata[['stool_consistency']], left_index=True, right_index=True)

# %%
# collapse samples per sample_type - calculate average abundance

ko_a_meta_avg = ko_a_meta.groupby('stool_consistency').mean()
ec_a_meta_avg = ec_a_meta.groupby('stool_consistency').mean()
pa_a_meta_avg = pa_a_meta.groupby('stool_consistency').mean()
ko_na_meta_avg = ko_na_meta.groupby('stool_consistency').mean()
ec_na_meta_avg = ec_na_meta.groupby('stool_consistency').mean()
pa_na_meta_avg = pa_na_meta.groupby('stool_consistency').mean()

# %%
ko_a_meta_avg
# Out:
#                          K00001      K00002        K00003       K00004  \
# stool_consistency
# formed              6037.306790  773.656380  20189.709305  2051.262596
# liquid             18708.284957  529.118973  28660.095238  2850.176466
# semi-formed        27573.876340  190.813369  19447.748558  5223.539693
#
#                          K00005     K00007        K00008        K00009  \
# stool_consistency
# formed             11894.709954   0.817587  29769.856206  16085.548045
# liquid             21045.077804  17.110777  43873.721815  24820.053589
# semi-formed        10406.258055  19.993414  15489.318023  10327.139551
#
#                          K00010    K00011  ...      K19777      K19778  \
# stool_consistency                          ...
# formed             12866.066883  0.040517  ...  343.760265  346.835130
# liquid             13028.297977  0.020591  ...   15.907100  561.045843
# semi-formed         8483.660044  0.000058  ...   70.334807   85.938083
#
#                       K19779      K19780       K19784         K19785  \
# stool_consistency
# formed             84.681018  343.471666  2282.388267   0.000000e+00
# liquid              3.651652   15.008893  2734.697251   3.854027e-04
# semi-formed        16.743543   66.983448  9193.116584  7.763663e-132
#
#                      K19787        K19788      K19789    K19791
# stool_consistency
# formed             0.000000  0.000000e+00  513.854295  0.000347
# liquid             0.000478  3.267224e-65  341.382649  0.003919
# semi-formed        0.000000  1.435881e-61  273.870191  0.003988
#
# [3 rows x 10251 columns]

# %%
ko_na_meta_avg
# Out:
#                          K00001     K00002        K00003        K00004  \
# stool_consistency
# formed             10147.006150  38.277427  28631.098128  15020.481029
# liquid             17736.375188  93.757042  50932.307112  27855.875670
# semi-formed        13643.017988  99.836616  29046.519817  15155.787109
#
#                          K00005     K00007        K00008        K00009  \
# stool_consistency
# formed             18270.325950  24.834485  22120.136212  22564.353026
# liquid             18077.871448   1.568945  49075.026567  48127.915567
# semi-formed        12060.491574   2.578626  18869.624145  19745.890068
#
#                          K00010        K00011  ...       K19776       K19777  \
# stool_consistency                              ...
# formed             14162.836028  1.333052e-21  ...  3313.347149  1577.393486
# liquid              9740.345325  1.499965e-03  ...   130.917774    10.554224
# semi-formed         8253.719387  6.192900e-21  ...    64.856889    12.767183
#
#                         K19778      K19779       K19780        K19784  \
# stool_consistency
# formed             1586.251307  343.858760  1414.225607   9928.389741
# liquid               50.823766    2.131272     8.428592  15485.064326
# semi-formed          37.792601    3.127061    12.390128   7047.888993
#
#                      K19785        K19788       K19789    K19791
# stool_consistency
# formed             0.000000  0.000000e+00  3350.177255  0.000102
# liquid             0.022468  7.790385e-59   243.304554  0.003744
# semi-formed        0.000000  0.000000e+00   140.924726  0.047428
#
# [3 rows x 9847 columns]

# %%
! qiime composition ancom \
    --i-table $data_dir/picrust2_results/pathway_abundance_abducted_abund.qza \
    --m-metadata-file $data_dir/metadata/str_nan_metadata.tsv \
    --m-metadata-column stool_consistency \
    --p-transform-function log \
    --o-visualization $data_dir/pa_ancom_abducted_stool_consistency.qzv

! qiime composition ancom \
    --i-table $data_dir/picrust2_results/pathway_abundance_not_abducted_abund.qza \
    --m-metadata-file $data_dir/metadata/str_nan_metadata.tsv \
    --m-metadata-column stool_consistency \
    --p-transform-function log \
    --o-visualization $data_dir/pa_ancom_not_abducted_stool_consistency.qzv
# Out:
# Saved Visualization to: shared_data//pa_ancom_abducted_stool_consistency.qzv
# Saved Visualization to: shared_data//pa_ancom_not_abducted_stool_consistency.qzv

# %%
Visualization.load(f'{data_dir}/pa_ancom_abducted_stool_consistency.qzv')
# Out:
# <visualization: Visualization uuid: 6d3f18e9-dfc6-4c96-9127-b0b897e5951f>

# %%
Visualization.load(f'{data_dir}/pa_ancom_not_abducted_stool_consistency.qzv')
# Out:
# <visualization: Visualization uuid: ac8b2dac-d207-419d-b804-f3c05fe09237>

# %% [markdown]
# ## 3. Functional Inference on Categorical categorical Time Relative to Engraftment

# %%
ko_a_meta = ko_a.merge(metadata[['categorical_time_relative_to_engraftment']], left_index=True, right_index=True)
ec_a_meta = ec_a.merge(metadata[['categorical_time_relative_to_engraftment']], left_index=True, right_index=True)
pa_a_meta = pa_a.merge(metadata[['categorical_time_relative_to_engraftment']], left_index=True, right_index=True)
ko_na_meta = ko_na.merge(metadata[['categorical_time_relative_to_engraftment']], left_index=True, right_index=True)
ec_na_meta = ec_na.merge(metadata[['categorical_time_relative_to_engraftment']], left_index=True, right_index=True)
pa_na_meta = pa_na.merge(metadata[['categorical_time_relative_to_engraftment']], left_index=True, right_index=True)

# %%
# collapse samples per sample_type - calculate average abundance

ko_a_meta_avg = ko_a_meta.groupby('categorical_time_relative_to_engraftment').mean()
ec_a_meta_avg = ec_a_meta.groupby('categorical_time_relative_to_engraftment').mean()
pa_a_meta_avg = pa_a_meta.groupby('categorical_time_relative_to_engraftment').mean()
ko_na_meta_avg = ko_na_meta.groupby('categorical_time_relative_to_engraftment').mean()
ec_na_meta_avg = ec_na_meta.groupby('categorical_time_relative_to_engraftment').mean()
pa_na_meta_avg = pa_na_meta.groupby('categorical_time_relative_to_engraftment').mean()

# %%
ko_a_meta_avg
# Out:
#                                                 K00001       K00002  \
# categorical_time_relative_to_engraftment
# peri                                       2114.150651   335.571804
# post                                      38891.568070  1018.573990
# pre                                        3349.070585   360.714580
#
#                                                 K00003       K00004  \
# categorical_time_relative_to_engraftment
# peri                                       6704.060157   648.476811
# post                                      48330.342573  7486.202129
# pre                                       10606.952331  1018.165276
#
#                                                 K00005     K00007  \
# categorical_time_relative_to_engraftment
# peri                                       3622.080928   1.320137
# post                                      32076.200421  29.300452
# pre                                        5988.067033   0.595760
#
#                                                 K00008        K00009  \
# categorical_time_relative_to_engraftment
# peri                                      12160.841250   7810.594355
# post                                      62746.992648  40142.072759
# pre                                       14760.258998   5155.612975
#
#                                                 K00010    K00011  ...  \
# categorical_time_relative_to_engraftment                          ...
# peri                                       5321.334654  0.000011  ...
# post                                      22515.633123  0.077798  ...
# pre                                        6561.072315  0.001120  ...
#
#                                               K19777       K19778      K19779  \
# categorical_time_relative_to_engraftment
# peri                                       31.153772    46.877726    7.337195
# post                                      556.583222  1015.152726  136.602004
# pre                                        14.079083    17.604554    3.483824
#
#                                               K19780        K19784    K19785  \
# categorical_time_relative_to_engraftment
# peri                                       29.352181    932.024107  0.000000
# post                                      554.017200  11353.594292  0.000323
# pre                                        13.948624    614.715979  0.000000
#
#                                           K19787        K19788       K19789  \
# categorical_time_relative_to_engraftment
# peri                                      0.0000  0.000000e+00    81.919162
# post                                      0.0004  1.102229e-61  1114.385819
# pre                                       0.0000  0.000000e+00    78.476669
#
#                                             K19791
# categorical_time_relative_to_engraftment
# peri                                      0.000097
# post                                      0.006685
# pre                                       0.000082
#
# [3 rows x 10251 columns]

# %%
ko_na_meta_avg
# Out:
#                                                 K00001      K00002  \
# categorical_time_relative_to_engraftment
# peri                                       1071.346104  152.465120
# post                                      20671.457512   71.474948
# pre                                        1493.628627   62.682144
#
#                                                 K00003        K00004  \
# categorical_time_relative_to_engraftment
# peri                                       8949.881683   2133.061097
# post                                      50965.499933  28947.815703
# pre                                        9265.847245   1459.460499
#
#                                                 K00005     K00007  \
# categorical_time_relative_to_engraftment
# peri                                       4159.275767   0.000000
# post                                      21931.421817  12.972971
# pre                                        5349.312766   2.577253
#
#                                                 K00008        K00009  \
# categorical_time_relative_to_engraftment
# peri                                      20253.321044   9911.320896
# post                                      37881.680954  41307.699574
# pre                                       13952.401125   9902.369913
#
#                                                 K00010        K00011  ...  \
# categorical_time_relative_to_engraftment                              ...
# peri                                       7723.821127  1.032150e-21  ...
# post                                      12875.523434  7.940989e-04  ...
# pre                                        5532.318145  0.000000e+00  ...
#
#                                                K19776      K19777      K19778  \
# categorical_time_relative_to_engraftment
# peri                                         2.666667    2.673357    2.666667
# post                                      1661.409336  754.177675  792.338813
# pre                                          2.798408    0.000000    1.632991
#
#                                               K19779      K19780  \
# categorical_time_relative_to_engraftment
# peri                                        0.665968    2.665910
# post                                      164.482187  676.069153
# pre                                         0.000000    0.000000
#
#                                                 K19784    K19785  \
# categorical_time_relative_to_engraftment
# peri                                       1445.448955  0.000000
# post                                      15965.293801  0.011895
# pre                                        1079.559387  0.000000
#
#                                                 K19788       K19789    K19791
# categorical_time_relative_to_engraftment
# peri                                      0.000000e+00     2.673435  0.000079
# post                                      4.124322e-59  1776.659257  0.027125
# pre                                       0.000000e+00     8.042315  0.000000
#
# [3 rows x 9847 columns]

# %%
! qiime composition ancom \
    --i-table $data_dir/picrust2_results/pathway_abundance_abducted_abund.qza \
    --m-metadata-file $data_dir/metadata/str_nan_metadata.tsv \
    --m-metadata-column categorical_time_relative_to_engraftment \
    --p-transform-function log \
    --o-visualization $data_dir/pa_ancom_abducted_categorical_time.qzv

! qiime composition ancom \
    --i-table $data_dir/picrust2_results/pathway_abundance_not_abducted_abund.qza \
    --m-metadata-file $data_dir/metadata/str_nan_metadata.tsv \
    --m-metadata-column categorical_time_relative_to_engraftment \
    --p-transform-function log \
    --o-visualization $data_dir/pa_ancom_not_abducted_categorical_time.qzv
# Out:
# Saved Visualization to: shared_data//pa_ancom_abducted_categorical_time.qzv
# Saved Visualization to: shared_data//pa_ancom_not_abducted_categorical_time.qzv

# %%
Visualization.load(f'{data_dir}/pa_ancom_abducted_categorical_time.qzv')
# Out:
# <visualization: Visualization uuid: 3988bff9-d266-4f6e-99cb-646a0b9b3674>

# %%
Visualization.load(f'{data_dir}/pa_ancom_not_abducted_categorical_time.qzv')
# Out:
# <visualization: Visualization uuid: 28882149-f4f0-48bb-8c61-27706c826af9>
