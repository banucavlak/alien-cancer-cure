# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt
import numpy as np

import qiime2 as q2

# %matplotlib inline

# %%
data_dir = 'Alien_data'

if not os.path.isdir(data_dir):
    os.makedirs(data_dir)

# %%
! wget -nv -O $data_dir/sequences.qza 'https://polybox.ethz.ch/index.php/s/PCQspFMocVCKjZ3/download'
# Out:
# 2022-10-17 17:38:52 URL:https://polybox.ethz.ch/index.php/s/PCQspFMocVCKjZ3/download [3433846903/3433846903] -> "Alien_data/sequences.qza" [1]

# %%
! wget -nv -O $data_dir/sample_metadata.tsv 'https://polybox.ethz.ch/index.php/s/r1AYzdUVWnQyiRL/download'
# Out:
# 2022-10-10 19:45:54 URL:https://polybox.ethz.ch/index.php/s/r1AYzdUVWnQyiRL/download [10012/10012] -> "Alien_data/sample_metadata.tsv" [1]

# %%
metadata_df = pd.read_csv(f'{data_dir}/sample_metadata.tsv', sep='\t')

# %%
! qiime tools peek $data_dir/sequences.qza
# Out:
# UUID:        394c4773-80e2-46a6-9fba-40e7c8ec3fb9
# Type:        SampleData[PairedEndSequencesWithQuality]
# Data format: SingleLanePerSamplePairedEndFastqDirFmt

# %%
! qiime demux summarize \
    --i-data $data_dir/sequences.qza \
    --o-visualization $data_dir/sequences.qzv
# Out:
# Saved Visualization to: Alien_data/sequences.qzv

# %%
Visualization.load(f'{data_dir}/sequences.qzv')
# Out:
# <visualization: Visualization uuid: 3e2d23ea-b49d-454f-9b2b-3a4288c37e57>

# %% [markdown]
# Cutadapt is used to trime out the forward and reverse primers:

# %%
! qiime cutadapt trim-paired \
  --i-demultiplexed-sequences $data_dir/sequences.qza \
  --p-front-f AYTGGGYDTAAAGNG \
  --p-front-r CCGTCAATTYHTTTRAGT \
  --p-error-rate 0 \
  --o-trimmed-sequences $data_dir/primer-trimmed-seqs.qza \
  --verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0DOSLC_113_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0DOSLC_274_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0DOSLC_113_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0DOSLC_274_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0DOSLC_113_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0DOSLC_274_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0DOSLC_113_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0DOSLC_274_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:17       426,984 reads @  41.0 µs/read;   1.46 M reads/minute
# Finished in 17.53 s (41 µs/read; 1.46 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            426,984
#   Read 1 with adapter:                 380,484 (89.1%)
#   Read 2 with adapter:                       3 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):       426,984 (100.0%)
#
# Total basepairs processed:   185,587,213 bp
#   Read 1:    92,310,225 bp
#   Read 2:    93,276,988 bp
# Total written (filtered):    184,064,975 bp (99.2%)
#   Read 1:    90,788,163 bp
#   Read 2:    93,276,812 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 380484 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	141	6671.6	0	141
# 4	380335	1667.9	0	380335
# 9	2	1.6	0	2
# 26	1	0.0	0	1
# 27	1	0.0	0	1
# 34	2	0.0	0	2
# 79	1	0.0	0	1
# 81	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 3 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 32	2	0.0	0	2
# 112	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0KB68F_12_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0KB68F_173_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0KB68F_12_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0KB68F_173_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0KB68F_12_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0KB68F_173_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0KB68F_12_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0KB68F_173_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        14,403 reads @  44.2 µs/read;   1.36 M reads/minute
# Finished in 0.64 s (45 µs/read; 1.34 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             14,403
#   Read 1 with adapter:                   9,738 (67.6%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        14,403 (100.0%)
#
# Total basepairs processed:     6,289,693 bp
#   Read 1:     3,203,519 bp
#   Read 2:     3,086,174 bp
# Total written (filtered):      6,250,539 bp (99.4%)
#   Read 1:     3,164,365 bp
#   Read 2:     3,086,174 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 9738 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	38	225.0	0	38
# 4	9698	56.3	0	9698
# 72	1	0.0	0	1
# 176	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0TR6O2_22_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0TR6O2_183_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0TR6O2_22_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0TR6O2_183_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0TR6O2_22_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0TR6O2_183_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0TR6O2_22_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0TR6O2_183_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        58,026 reads @  47.7 µs/read;   1.26 M reads/minute
# Finished in 2.77 s (48 µs/read; 1.26 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             58,026
#   Read 1 with adapter:                  21,748 (37.5%)
#   Read 2 with adapter:                       3 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        58,026 (100.0%)
#
# Total basepairs processed:    25,197,074 bp
#   Read 1:    12,599,587 bp
#   Read 2:    12,597,487 bp
# Total written (filtered):     25,109,979 bp (99.7%)
#   Read 1:    12,512,510 bp
#   Read 2:    12,597,469 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 21748 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	171	906.7	0	171
# 4	21575	226.7	0	21575
# 89	1	0.0	0	1
# 175	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 3 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	3	14.2	0	3
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0UWI7J_137_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0UWI7J_298_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0UWI7J_137_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0UWI7J_298_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0UWI7J_137_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0UWI7J_298_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0UWI7J_137_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0UWI7J_298_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        54,689 reads @  45.9 µs/read;   1.31 M reads/minute
# Finished in 2.52 s (46 µs/read; 1.30 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             54,689
#   Read 1 with adapter:                  16,403 (30.0%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        54,689 (100.0%)
#
# Total basepairs processed:    23,771,644 bp
#   Read 1:    11,823,597 bp
#   Read 2:    11,948,047 bp
# Total written (filtered):     23,705,892 bp (99.7%)
#   Read 1:    11,757,845 bp
#   Read 2:    11,948,047 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 16403 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	126	854.5	0	126
# 4	16275	213.6	0	16275
# 99	1	0.0	0	1
# 175	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0WG67D_62_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0WG67D_223_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0WG67D_62_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0WG67D_223_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0WG67D_62_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0WG67D_223_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0WG67D_62_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0WG67D_223_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:14       343,141 reads @  41.9 µs/read;   1.43 M reads/minute
# Finished in 14.39 s (42 µs/read; 1.43 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            343,141
#   Read 1 with adapter:                 316,708 (92.3%)
#   Read 2 with adapter:                       2 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):       343,141 (100.0%)
#
# Total basepairs processed:   149,062,534 bp
#   Read 1:    75,506,181 bp
#   Read 2:    73,556,353 bp
# Total written (filtered):    147,795,365 bp (99.1%)
#   Read 1:    74,239,077 bp
#   Read 2:    73,556,288 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 316708 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	66	5361.6	0	66
# 4	316635	1340.4	0	316635
# 30	6	0.0	0	6
# 186	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 2 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 29	1	0.0	0	1
# 36	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0ZIEYD_135_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0ZIEYD_296_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0ZIEYD_135_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0ZIEYD_296_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0ZIEYD_135_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/0ZIEYD_296_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0ZIEYD_135_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/0ZIEYD_296_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        31,219 reads @  51.5 µs/read;   1.17 M reads/minute
# Finished in 1.61 s (52 µs/read; 1.16 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             31,219
#   Read 1 with adapter:                  13,433 (43.0%)
#   Read 2 with adapter:                       3 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        31,219 (100.0%)
#
# Total basepairs processed:    13,560,857 bp
#   Read 1:     6,809,472 bp
#   Read 2:     6,751,385 bp
# Total written (filtered):     13,507,153 bp (99.6%)
#   Read 1:     6,755,786 bp
#   Read 2:     6,751,367 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 13433 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	46	487.8	0	46
# 4	13387	121.9	0	13387
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 3 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	3	7.6	0	3
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12H3HH_151_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12H3HH_312_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12H3HH_151_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12H3HH_312_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12H3HH_151_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12H3HH_312_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12H3HH_151_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12H3HH_312_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        25,545 reads @  46.7 µs/read;   1.29 M reads/minute
# Finished in 1.20 s (47 µs/read; 1.28 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             25,545
#   Read 1 with adapter:                  23,320 (91.3%)
#   Read 2 with adapter:                       1 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        25,545 (100.0%)
#
# Total basepairs processed:    11,098,881 bp
#   Read 1:     5,596,167 bp
#   Read 2:     5,502,714 bp
# Total written (filtered):     11,005,197 bp (99.2%)
#   Read 1:     5,502,661 bp
#   Read 2:     5,502,536 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 23320 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	2	399.1	0	2
# 4	23316	99.8	0	23316
# 98	1	0.0	0	1
# 138	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 1 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 178	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12QINS_129_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12QINS_290_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12QINS_129_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12QINS_290_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12QINS_129_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12QINS_290_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12QINS_129_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12QINS_290_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        49,023 reads @  46.7 µs/read;   1.28 M reads/minute
# Finished in 2.30 s (47 µs/read; 1.28 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             49,023
#   Read 1 with adapter:                  48,304 (98.5%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        49,023 (100.0%)
#
# Total basepairs processed:    21,362,734 bp
#   Read 1:    10,742,070 bp
#   Read 2:    10,620,664 bp
# Total written (filtered):     21,169,540 bp (99.1%)
#   Read 1:    10,548,876 bp
#   Read 2:    10,620,664 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 48304 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	22	766.0	0	22
# 4	48282	191.5	0	48282
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12ZW3B_48_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12ZW3B_209_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12ZW3B_48_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12ZW3B_209_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12ZW3B_48_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/12ZW3B_209_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12ZW3B_48_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/12ZW3B_209_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00        19,511 reads @  46.9 µs/read;   1.28 M reads/minute
# Finished in 0.92 s (47 µs/read; 1.27 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             19,511
#   Read 1 with adapter:                  17,963 (92.1%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        19,511 (100.0%)
#
# Total basepairs processed:     8,479,351 bp
#   Read 1:     4,312,688 bp
#   Read 2:     4,166,663 bp
# Total written (filtered):      8,407,659 bp (99.2%)
#   Read 1:     4,240,996 bp
#   Read 2:     4,166,663 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 17963 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	160	304.9	0	160
# 4	17803	76.2	0	17803
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1IMOSV_49_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1IMOSV_210_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1IMOSV_49_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1IMOSV_210_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1IMOSV_49_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1IMOSV_210_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1IMOSV_49_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1IMOSV_210_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00         8,849 reads @  55.4 µs/read;   1.08 M reads/minute
# Finished in 0.50 s (56 µs/read; 1.07 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              8,849
#   Read 1 with adapter:                   4,606 (52.1%)
#   Read 2 with adapter:                       1 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):         8,849 (100.0%)
#
# Total basepairs processed:     3,858,998 bp
#   Read 1:     1,950,881 bp
#   Read 2:     1,908,117 bp
# Total written (filtered):      3,840,529 bp (99.5%)
#   Read 1:     1,932,418 bp
#   Read 2:     1,908,111 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 4606 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	22	138.3	0	22
# 4	4583	34.6	0	4583
# 65	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 1 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	2.2	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1Y2WWO_100_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1Y2WWO_261_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1Y2WWO_100_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1Y2WWO_261_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1Y2WWO_100_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/1Y2WWO_261_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1Y2WWO_100_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/1Y2WWO_261_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:04        71,633 reads @  56.2 µs/read;   1.07 M reads/minute
# Finished in 4.03 s (56 µs/read; 1.07 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             71,633
#   Read 1 with adapter:                  36,670 (51.2%)
#   Read 2 with adapter:                       2 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        71,633 (100.0%)
#
# Total basepairs processed:    31,189,795 bp
#   Read 1:    15,906,407 bp
#   Read 2:    15,283,388 bp
# Total written (filtered):     31,042,940 bp (99.5%)
#   Read 1:    15,759,821 bp
#   Read 2:    15,283,119 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 36670 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	170	1119.3	0	170
# 4	36497	279.8	0	36497
# 27	2	0.0	0	2
# 34	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 2 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 84	1	0.0	0	1
# 185	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2FPVDT_144_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2FPVDT_305_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2FPVDT_144_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2FPVDT_305_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2FPVDT_144_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2FPVDT_305_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2FPVDT_144_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2FPVDT_305_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:04        79,901 reads @  52.1 µs/read;   1.15 M reads/minute
# Finished in 4.17 s (52 µs/read; 1.15 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             79,901
#   Read 1 with adapter:                  43,420 (54.3%)
#   Read 2 with adapter:                       2 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        79,901 (100.0%)
#
# Total basepairs processed:    34,712,235 bp
#   Read 1:    17,659,777 bp
#   Read 2:    17,052,458 bp
# Total written (filtered):     34,538,616 bp (99.5%)
#   Read 1:    17,486,170 bp
#   Read 2:    17,052,446 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 43420 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	73	1248.5	0	73
# 4	43347	312.1	0	43347
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 2 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	2	19.5	0	2
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2I7SIQ_3_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2I7SIQ_164_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2I7SIQ_3_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2I7SIQ_164_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2I7SIQ_3_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2I7SIQ_164_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2I7SIQ_3_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2I7SIQ_164_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        36,270 reads @  47.1 µs/read;   1.27 M reads/minute
# Finished in 1.71 s (47 µs/read; 1.27 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             36,270
#   Read 1 with adapter:                  24,351 (67.1%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        36,270 (100.0%)
#
# Total basepairs processed:    15,803,617 bp
#   Read 1:     8,035,264 bp
#   Read 2:     7,768,353 bp
# Total written (filtered):     15,705,939 bp (99.4%)
#   Read 1:     7,937,586 bp
#   Read 2:     7,768,353 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 24351 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	24	566.7	0	24
# 4	24322	141.7	0	24322
# 27	2	0.0	0	2
# 62	1	0.0	0	1
# 93	1	0.0	0	1
# 109	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2M59XO_26_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2M59XO_187_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2M59XO_26_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2M59XO_187_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2M59XO_26_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2M59XO_187_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2M59XO_26_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2M59XO_187_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:19       383,470 reads @  49.8 µs/read;   1.20 M reads/minute
# Finished in 19.11 s (50 µs/read; 1.20 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            383,470
#   Read 1 with adapter:                 181,806 (47.4%)
#   Read 2 with adapter:                       2 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):       383,470 (100.0%)
#
# Total basepairs processed:   166,508,616 bp
#   Read 1:    83,633,468 bp
#   Read 2:    82,875,148 bp
# Total written (filtered):    165,781,156 bp (99.6%)
#   Read 1:    82,906,057 bp
#   Read 2:    82,875,099 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 181806 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	285	5991.7	0	285
# 4	181513	1497.9	0	181513
# 5	2	374.5	0	2
# 18	1	0.0	0	1
# 32	1	0.0	0	1
# 45	1	0.0	0	1
# 49	1	0.0	0	1
# 175	2	0.0	0	2
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 2 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	93.6	0	1
# 43	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2ZT5IF_29_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2ZT5IF_190_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2ZT5IF_29_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2ZT5IF_190_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2ZT5IF_29_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/2ZT5IF_190_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2ZT5IF_29_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/2ZT5IF_190_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        49,462 reads @  50.4 µs/read;   1.19 M reads/minute
# Finished in 2.50 s (51 µs/read; 1.19 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             49,462
#   Read 1 with adapter:                  37,025 (74.9%)
#   Read 2 with adapter:                       4 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        49,462 (100.0%)
#
# Total basepairs processed:    21,534,626 bp
#   Read 1:    10,982,600 bp
#   Read 2:    10,552,026 bp
# Total written (filtered):     21,386,058 bp (99.3%)
#   Read 1:    10,834,342 bp
#   Read 2:    10,551,716 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 37025 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	51	772.8	0	51
# 4	36972	193.2	0	36972
# 28	1	0.0	0	1
# 189	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 4 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	2	12.1	0	2
# 110	1	0.0	0	1
# 188	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ALGNE_142_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ALGNE_303_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ALGNE_142_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ALGNE_303_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ALGNE_142_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ALGNE_303_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ALGNE_142_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ALGNE_303_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:18       395,575 reads @  46.0 µs/read;   1.30 M reads/minute
# Finished in 18.20 s (46 µs/read; 1.30 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            395,575
#   Read 1 with adapter:                 337,536 (85.3%)
#   Read 2 with adapter:                       8 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):       395,575 (100.0%)
#
# Total basepairs processed:   171,955,103 bp
#   Read 1:    85,534,626 bp
#   Read 2:    86,420,477 bp
# Total written (filtered):    170,605,915 bp (99.2%)
#   Read 1:    84,185,862 bp
#   Read 2:    86,420,053 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 337536 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	2102	6180.9	0	2102
# 4	335425	1545.2	0	335425
# 17	1	0.0	0	1
# 34	2	0.0	0	2
# 79	2	0.0	0	2
# 87	1	0.0	0	1
# 108	1	0.0	0	1
# 119	1	0.0	0	1
# 201	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 8 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	96.6	0	1
# 8	1	6.0	0	1
# 27	1	0.0	0	1
# 28	1	0.0	0	1
# 29	1	0.0	0	1
# 74	1	0.0	0	1
# 80	1	0.0	0	1
# 172	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3CGEF6_104_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3CGEF6_265_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3CGEF6_104_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3CGEF6_265_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3CGEF6_104_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3CGEF6_265_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3CGEF6_104_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3CGEF6_265_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:03        67,627 reads @  49.8 µs/read;   1.21 M reads/minute
# Finished in 3.37 s (50 µs/read; 1.20 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             67,627
#   Read 1 with adapter:                   6,239 (9.2%)
#   Read 2 with adapter:                       2 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        67,627 (100.0%)
#
# Total basepairs processed:    29,375,776 bp
#   Read 1:    14,881,045 bp
#   Read 2:    14,494,731 bp
# Total written (filtered):     29,350,729 bp (99.9%)
#   Read 1:    14,856,207 bp
#   Read 2:    14,494,522 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 6239 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	118	1056.7	0	118
# 4	6121	264.2	0	6121
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 2 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 103	1	0.0	0	1
# 106	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3DFM85_54_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3DFM85_215_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3DFM85_54_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3DFM85_215_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3DFM85_54_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3DFM85_215_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3DFM85_54_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3DFM85_215_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        22,916 reads @  49.2 µs/read;   1.22 M reads/minute
# Finished in 1.13 s (49 µs/read; 1.21 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             22,916
#   Read 1 with adapter:                  16,459 (71.8%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        22,916 (100.0%)
#
# Total basepairs processed:     9,954,042 bp
#   Read 1:     5,044,217 bp
#   Read 2:     4,909,825 bp
# Total written (filtered):      9,888,221 bp (99.3%)
#   Read 1:     4,978,396 bp
#   Read 2:     4,909,825 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 16459 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	15	358.1	0	15
# 4	16444	89.5	0	16444
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3XK7UB_153_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3XK7UB_314_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3XK7UB_153_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3XK7UB_314_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3XK7UB_153_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3XK7UB_314_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3XK7UB_153_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3XK7UB_314_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:15       335,450 reads @  46.2 µs/read;   1.30 M reads/minute
# Finished in 15.52 s (46 µs/read; 1.30 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            335,450
#   Read 1 with adapter:                  72,609 (21.6%)
#   Read 2 with adapter:                       2 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):       335,450 (100.0%)
#
# Total basepairs processed:   146,090,984 bp
#   Read 1:    73,503,994 bp
#   Read 2:    72,586,990 bp
# Total written (filtered):    145,800,923 bp (99.8%)
#   Read 1:    73,213,973 bp
#   Read 2:    72,586,950 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 72609 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	675	5241.4	0	675
# 4	71930	1310.4	0	71930
# 11	1	0.1	0	1
# 22	1	0.0	0	1
# 53	1	0.0	0	1
# 190	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 2 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 6	1	81.9	0	1
# 34	1	0.0	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ZQWO3_42_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ZQWO3_203_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ZQWO3_42_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ZQWO3_203_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ZQWO3_42_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/3ZQWO3_203_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ZQWO3_42_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/3ZQWO3_203_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        39,380 reads @  46.8 µs/read;   1.28 M reads/minute
# Finished in 1.85 s (47 µs/read; 1.28 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             39,380
#   Read 1 with adapter:                  33,348 (84.7%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        39,380 (100.0%)
#
# Total basepairs processed:    17,162,091 bp
#   Read 1:     8,630,145 bp
#   Read 2:     8,531,946 bp
# Total written (filtered):     17,028,516 bp (99.2%)
#   Read 1:     8,496,570 bp
#   Read 2:     8,531,946 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 33348 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	33	615.3	0	33
# 4	33314	153.8	0	33314
# 220	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/4JX8MN_140_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/4JX8MN_301_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/4JX8MN_140_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/4JX8MN_301_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/4JX8MN_140_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/4JX8MN_301_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/4JX8MN_140_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/4JX8MN_301_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        45,505 reads @  49.2 µs/read;   1.22 M reads/minute
# Finished in 2.24 s (49 µs/read; 1.22 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             45,505
#   Read 1 with adapter:                  32,783 (72.0%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        45,505 (100.0%)
#
# Total basepairs processed:    19,781,662 bp
#   Read 1:     9,968,809 bp
#   Read 2:     9,812,853 bp
# Total written (filtered):     19,650,617 bp (99.3%)
#   Read 1:     9,837,764 bp
#   Read 2:     9,812,853 bp
#
# === First read: Adapter 1 ===
#
# ...
#
# Total basepairs processed:     9,614,685 bp
#   Read 1:     4,826,956 bp
#   Read 2:     4,787,729 bp
# Total written (filtered):      9,558,062 bp (99.4%)
#   Read 1:     4,770,333 bp
#   Read 2:     4,787,729 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 14161 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	21	345.8	0	21
# 4	14140	86.5	0	14140
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/YLLVZM_19_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/YLLVZM_180_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/YLLVZM_19_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/YLLVZM_180_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/YLLVZM_19_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/YLLVZM_180_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/YLLVZM_19_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/YLLVZM_180_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        45,023 reads @  45.6 µs/read;   1.31 M reads/minute
# Finished in 2.06 s (46 µs/read; 1.31 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             45,023
#   Read 1 with adapter:                  34,021 (75.6%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        45,023 (100.0%)
#
# Total basepairs processed:    19,610,053 bp
#   Read 1:     9,998,652 bp
#   Read 2:     9,611,401 bp
# Total written (filtered):     19,474,077 bp (99.3%)
#   Read 1:     9,862,676 bp
#   Read 2:     9,611,401 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 34021 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	108	703.5	0	108
# 4	33913	175.9	0	33913
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z2DXHY_28_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z2DXHY_189_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z2DXHY_28_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z2DXHY_189_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z2DXHY_28_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z2DXHY_189_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z2DXHY_28_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z2DXHY_189_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        48,860 reads @  48.5 µs/read;   1.24 M reads/minute
# Finished in 2.38 s (49 µs/read; 1.23 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             48,860
#   Read 1 with adapter:                  47,728 (97.7%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        48,860 (100.0%)
#
# Total basepairs processed:    21,232,291 bp
#   Read 1:    10,561,079 bp
#   Read 2:    10,671,212 bp
# Total written (filtered):     21,041,181 bp (99.1%)
#   Read 1:    10,369,969 bp
#   Read 2:    10,671,212 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 47728 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	12	763.4	0	12
# 4	47714	190.9	0	47714
# 75	1	0.0	0	1
# 143	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z95BTZ_138_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z95BTZ_299_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z95BTZ_138_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z95BTZ_299_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z95BTZ_138_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z95BTZ_299_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z95BTZ_138_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z95BTZ_299_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:01        26,178 reads @  42.6 µs/read;   1.41 M reads/minute
# Finished in 1.12 s (43 µs/read; 1.40 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             26,178
#   Read 1 with adapter:                     447 (1.7%)
#   Read 2 with adapter:                       1 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        26,178 (100.0%)
#
# Total basepairs processed:    11,368,415 bp
#   Read 1:     5,632,997 bp
#   Read 2:     5,735,418 bp
# Total written (filtered):     11,366,620 bp (100.0%)
#   Read 1:     5,631,209 bp
#   Read 2:     5,735,411 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 447 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 4	447	102.3	0	447
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 1 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-18 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 7	1	1.6	0	1
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z9874X_57_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z9874X_218_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z9874X_57_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z9874X_218_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z9874X_57_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/Z9874X_218_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z9874X_57_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/Z9874X_218_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00         8,337 reads @  47.3 µs/read;   1.27 M reads/minute
# Finished in 0.40 s (48 µs/read; 1.25 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              8,337
#   Read 1 with adapter:                   3,943 (47.3%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):         8,337 (100.0%)
#
# Total basepairs processed:     3,632,862 bp
#   Read 1:     1,853,321 bp
#   Read 2:     1,779,541 bp
# Total written (filtered):      3,617,010 bp (99.6%)
#   Read 1:     1,837,469 bp
#   Read 2:     1,779,541 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 3943 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	8	130.3	0	8
# 4	3934	32.6	0	3934
# 92	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZJYE4E_143_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZJYE4E_304_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZJYE4E_143_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZJYE4E_304_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZJYE4E_143_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZJYE4E_304_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZJYE4E_143_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZJYE4E_304_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:02        53,153 reads @  47.1 µs/read;   1.27 M reads/minute
# Finished in 2.51 s (47 µs/read; 1.27 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             53,153
#   Read 1 with adapter:                  19,450 (36.6%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):        53,153 (100.0%)
#
# Total basepairs processed:    23,108,041 bp
#   Read 1:    11,752,219 bp
#   Read 2:    11,355,822 bp
# Total written (filtered):     23,030,180 bp (99.7%)
#   Read 1:    11,674,358 bp
#   Read 2:    11,355,822 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 19450 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	116	830.5	0	116
# 4	19333	207.6	0	19333
# 181	1	0.0	0	1
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZKJI45_2_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZKJI45_163_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZKJI45_2_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZKJI45_163_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZKJI45_2_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZKJI45_163_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZKJI45_2_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZKJI45_163_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00         6,794 reads @  45.8 µs/read;   1.31 M reads/minute
# Finished in 0.32 s (47 µs/read; 1.28 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              6,794
#   Read 1 with adapter:                   6,536 (96.2%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):         6,794 (100.0%)
#
# Total basepairs processed:     2,976,851 bp
#   Read 1:     1,492,733 bp
#   Read 2:     1,484,118 bp
# Total written (filtered):      2,950,709 bp (99.1%)
#   Read 1:     1,466,591 bp
#   Read 2:     1,484,118 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 6536 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	2	106.2	0	2
# 4	6534	26.5	0	6534
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
#
# Command: cutadapt --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZQT8ZN_73_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZQT8ZN_234_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZQT8ZN_73_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZQT8ZN_234_L001_R2_001.fastq.gz
#
# This is cutadapt 4.0 with Python 3.8.13
# Command line parameters: --cores 1 --error-rate 0 --times 1 --overlap 3 --minimum-length 1 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZQT8ZN_73_L001_R1_001.fastq.gz -p /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-p4d5rt0g/ZQT8ZN_234_L001_R2_001.fastq.gz --front AYTGGGYDTAAAGNG -G CCGTCAATTYHTTTRAGT /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZQT8ZN_73_L001_R1_001.fastq.gz /tmp/qiime2-archive-we88jvpb/394c4773-80e2-46a6-9fba-40e7c8ec3fb9/data/ZQT8ZN_234_L001_R2_001.fastq.gz
# Processing paired-end reads on 1 core ...
# Done           00:00:00         3,252 reads @  45.9 µs/read;   1.31 M reads/minute
# Finished in 0.16 s (48 µs/read; 1.25 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:              3,252
#   Read 1 with adapter:                   2,434 (74.8%)
#   Read 2 with adapter:                       0 (0.0%)
#
# == Read fate breakdown ==
# Pairs that were too short:                   0 (0.0%)
# Pairs written (passing filters):         3,252 (100.0%)
#
# Total basepairs processed:     1,415,226 bp
#   Read 1:       718,916 bp
#   Read 2:       696,310 bp
# Total written (filtered):      1,405,492 bp (99.3%)
#   Read 1:       709,182 bp
#   Read 2:       696,310 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AYTGGGYDTAAAGNG; Type: regular 5'; Length: 15; Trimmed: 2434 times
#
# Minimum overlap: 3
# No. of allowed errors:
# 1-14 bp: 0
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 3	2	50.8	0	2
# 4	2432	12.7	0	2432
#
#
# === Second read: Adapter 2 ===
#
# Sequence: CCGTCAATTYHTTTRAGT; Type: regular 5'; Length: 18; Trimmed: 0 times
# Saved SampleData[PairedEndSequencesWithQuality] to: Alien_data/primer-trimmed-seqs.qza

# %%
! qiime demux summarize \
  --i-data $data_dir/primer-trimmed-seqs.qza \
  --o-visualization $data_dir/primer-trimmed-seqs.qzv
# Out:
# Saved Visualization to: Alien_data/primer-trimmed-seqs.qzv

# %%
Visualization.load(f'{data_dir}/primer-trimmed-seqs.qzv')
# Out:
# <visualization: Visualization uuid: a3e8ac5e-8ddf-4645-aca7-bc0bd3d885ca>

# %% [markdown]
# Dada 2 is used to denoise the paired-end sequences. The truncation length is selected based on median value of quality score larger than 30.

# %%
! qiime dada2 denoise-paired \
    --i-demultiplexed-seqs $data_dir/primer-trimmed-seqs.qza \
    --p-trunc-len-f 183 \
    --p-trunc-len-r 190 \
    --p-n-threads 4 \
    --o-table $data_dir/dada2_table.qza \
    --o-representative-sequences $data_dir/dada2_rep_set.qza \
    --o-denoising-stats $data_dir/dada2_stats.qza
# Out:
# Saved FeatureTable[Frequency] to: Alien_data/dada2_table.qza
# Saved FeatureData[Sequence] to: Alien_data/dada2_rep_set.qza
# Saved SampleData[DADA2Stats] to: Alien_data/dada2_stats.qza

# %%
! qiime metadata tabulate \
    --m-input-file $data_dir/dada2_stats.qza \
    --o-visualization $data_dir/dada2_stats.qzv
# Out:
# Saved Visualization to: Alien_data/dada2_stats.qzv

# %%
Visualization.load(f'{data_dir}/dada2_stats.qzv')
# Out:
# <visualization: Visualization uuid: 8f87926c-2fde-4497-bfe3-3c6ea402adfd>

# %%
! qiime feature-table summarize \
  --i-table $data_dir/dada2_table.qza \
  --o-visualization $data_dir/dada2_table.qzv
# Out:
# Saved Visualization to: Alien_data/dada2_table.qzv

# %%
Visualization.load(f'{data_dir}/dada2_table.qzv')
# Out:
# <visualization: Visualization uuid: 2a7f7529-81a8-47d3-a192-75249483c000>

# %%
! qiime feature-table tabulate-seqs \
  --i-data $data_dir/dada2_rep_set.qza \
  --o-visualization $data_dir/dada2_rep_set.qzv
# Out:
# Saved Visualization to: Alien_data/dada2_rep_set.qzv

# %%
Visualization.load(f'{data_dir}/dada2_rep_set.qzv')
# Out:
# <visualization: Visualization uuid: 92e1a1db-1b09-4bf5-869e-d75c9035d036>

# %%
Taxonomy classification:

# %% [markdown]
# Database curation:

# %%
! qiime rescript get-silva-data \
    --p-version '138.1' \
    --p-target 'SSURef_NR99' \
    --p-include-species-labels \
    --o-silva-sequences $data_dir/silva-138.1-ssu-nr99-rna-seqs.qza \
    --o-silva-taxonomy $data_dir/silva-138.1-ssu-nr99-tax.qza
# Out:
# Saved FeatureData[RNASequence] to: Alien_data/silva-138.1-ssu-nr99-rna-seqs.qza
# Saved FeatureData[Taxonomy] to: Alien_data/silva-138.1-ssu-nr99-tax.qza

# %%
 ! qiime rescript cull-seqs \
     --i-sequences $data_dir/silva-138.1-ssu-nr99-rna-seqs.qza \
     --p-num-degenerates 5 \
     --p-homopolymer-length 8 \
     --p-n-jobs 3 \
     --o-clean-sequences $data_dir/silva-138.1-ssu-nr99-rna-seqs-cleaned.qza
# Out:
# Saved FeatureData[Sequence] to: Alien_data/silva-138.1-ssu-nr99-rna-seqs-cleaned.qza

# %%
! qiime rescript filter-seqs-length-by-taxon \
    --i-sequences $data_dir/silva-138.1-ssu-nr99-rna-seqs-cleaned.qza \
    --i-taxonomy $data_dir/silva-138.1-ssu-nr99-tax.qza \
    --p-labels Archaea Bacteria Eukaryota \
    --p-min-lens 900 1200 1400 \
    --o-filtered-seqs $data_dir/silva-138-ssu-nr99-seqs-filt.qza \
    --o-discarded-seqs $data_dir/silva-138-ssu-nr99-seqs-discard.qza
# Out:
# Saved FeatureData[Sequence] to: Alien_data/silva-138-ssu-nr99-seqs-filt.qza
# Saved FeatureData[Sequence] to: Alien_data/silva-138-ssu-nr99-seqs-discard.qza

# %%
! qiime rescript dereplicate \
    --i-sequences $data_dir/silva-138-ssu-nr99-seqs-filt.qza  \
    --i-taxa $data_dir/silva-138.1-ssu-nr99-tax.qza \
    --p-rank-handles 'silva' \
    --p-mode 'uniq' \
    --p-threads 3 \
    --o-dereplicated-sequences $data_dir/silva-138-ssu-nr99-seqs-derep-uniq.qza \
    --o-dereplicated-taxa $data_dir/silva-138-ssu-nr99-tax-derep-uniq.qza
# Out:
# Saved FeatureData[Sequence] to: Alien_data/silva-138-ssu-nr99-seqs-derep-uniq.qza
# Saved FeatureData[Taxonomy] to: Alien_data/silva-138-ssu-nr99-tax-derep-uniq.qza

# %% [markdown]
# PCR extraction:
# The primers used for our samples are designed for the V4-V5 region:
# 563 F: 5′-AYTGGGYDTAAAGNG-3′
# 926 R: 5′-CCGTCAATTYHTTTRAGT-3′

# %%
! qiime feature-classifier extract-reads \
    --i-sequences $data_dir/silva-138-ssu-nr99-seqs-derep-uniq.qza \
    --p-f-primer AYTGGGYDTAAAGNG \
    --p-r-primer CCGTCAATTYHTTTRAGT \
    --p-n-jobs 3 \
    --p-read-orientation 'forward' \
    --o-reads $data_dir/silva-138-ssu-nr99-seqs-515f-806r.qza
# Out:
# Saved FeatureData[Sequence] to: Alien_data/silva-138-ssu-nr99-seqs-515f-806r.qza

# %%
! qiime rescript dereplicate \
    --i-sequences $data_dir/silva-138-ssu-nr99-seqs-515f-806r.qza \
    --i-taxa $data_dir/silva-138-ssu-nr99-tax-derep-uniq.qza \
    --p-rank-handles 'silva' \
    --p-mode 'uniq' \
    --p-threads 3 \
    --o-dereplicated-sequences $data_dir/silva-138-ssu-nr99-seqs-515f-806r-uniq.qza \
    --o-dereplicated-taxa  $data_dir/silva-138-ssu-nr99-tax-515f-806r-derep-uniq.qza
# Out:
# Saved FeatureData[Sequence] to: Alien_data/silva-138-ssu-nr99-seqs-515f-806r-uniq.qza
# Saved FeatureData[Taxonomy] to: Alien_data/silva-138-ssu-nr99-tax-515f-806r-derep-uniq.qza

# %% [markdown]
# We tried to use the silva database and train the classifers using naive bayes, but it exceeded the memory capacity to train the classifer and also to use the pre-trained Silva database, so we decided to use the pre-trained Greengene classifier.

# %%
#! qiime feature-classifier fit-classifier-naive-bayes \
#     --i-reference-reads $data_dir/silva-138-ssu-nr99-seqs-515f-806r-uniq.qza \
#     --i-reference-taxonomy $data_dir/silva-138-ssu-nr99-tax-515f-806r-derep-uniq.qza \
#     --p-classify--chunk-size 1000 \
#     --o-classifier $data_dir/515f-806r-classifier.qza

# %%
! wget -nv -O $data_dir/gg-13-8-99-nb-classifier.qza 'https://data.qiime2.org/2022.8/common/gg-13-8-99-nb-classifier.qza'
# Out:
# 2022-10-26 19:41:49 URL:https://s3-us-west-2.amazonaws.com/qiime2-data/2022.8/common/gg-13-8-99-nb-classifier.qza [104512483/104512483] -> "Alien_data/gg-13-8-99-nb-classifier.qza" [1]

# %%
! qiime feature-classifier classify-sklearn \
    --i-classifier $data_dir/gg-13-8-99-nb-classifier.qza \
    --i-reads $data_dir/dada2_rep_set.qza \
    --o-classification $data_dir/taxonomy.qza
# Out:
# Saved FeatureData[Taxonomy] to: Alien_data/taxonomy.qza

# %%
! qiime metadata tabulate \
    --m-input-file $data_dir/taxonomy.qza \
    --o-visualization $data_dir/taxonomy.qzv
# Out:
# Saved Visualization to: Alien_data/taxonomy.qzv

# %%
Visualization.load(f'{data_dir}/taxonomy.qzv')
# Out:
# <visualization: Visualization uuid: dd568eab-270d-4892-9f13-ae4bb3dc3822>

# %%
! qiime taxa barplot \
    --i-table $data_dir/dada2_table.qza \
    --i-taxonomy $data_dir/taxonomy.qza \
    --m-metadata-file $data_dir/sample_metadata.tsv \
    --o-visualization $data_dir/taxa-bar-plots.qzv
# Out:
# Saved Visualization to: Alien_data/taxa-bar-plots.qzv

# %%
Visualization.load(f'{data_dir}/taxa-bar-plots.qzv')
# Out:
# <visualization: Visualization uuid: 0f39b3b8-b8f7-4d8f-84e3-f77b18f1d391>

# %% [markdown]
# Mitochondira and chloroplast are filtered since they don't belong to the gut microbiota:

# %%
! qiime taxa filter-table \
    --i-table $data_dir/dada2_table.qza \
    --i-taxonomy $data_dir/taxonomy.qza \
    --p-exclude mitochondria,chloroplast \
    --o-filtered-table $data_dir/table-filtered.qza
# Out:
# Saved FeatureTable[Frequency] to: Alien_data/table-filtered.qza

# %%
! qiime taxa filter-seqs \
    --i-sequences $data_dir/dada2_rep_set.qza \
    --i-taxonomy $data_dir/taxonomy.qza \
    --p-exclude mitochondria,chloroplast \
    --o-filtered-sequences $data_dir/rep-seqs-filtered.qza
# Out:
# Saved FeatureData[Sequence] to: Alien_data/rep-seqs-filtered.qza

# %%
! qiime taxa barplot \
    --i-table $data_dir/table-filtered.qza \
    --i-taxonomy $data_dir/taxonomy.qza \
    --m-metadata-file $data_dir/sample_metadata.tsv \
    --o-visualization $data_dir/taxa-bar-plots_filtered.qzv
# Out:
# Saved Visualization to: Alien_data/taxa-bar-plots_filtered.qzv

# %%
Visualization.load(f'{data_dir}/taxa-bar-plots_filtered.qzv')
# Out:
# <visualization: Visualization uuid: 6bf8bdcd-fb82-4933-b20f-aa69ef72167c>
